# %% [markdown]
# <a href="https://colab.research.google.com/github/parrisatwork/parrisatwork-Prediction-of-Product-Sale/blob/main/Prediction_of_Product_Sales_Parris_Trimingham.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Prediction of Product Sales**

# %% [markdown]
# - **Author:** Parris Trimingham

# %% [markdown]
# ## **Project Overview**

# %% [markdown]
# ## Data Dictionary

# %% [markdown]
# ![Data Dictionary for Project.PNG](data:image/png;base64,...)

# %% [markdown]
# ## **Imports**

# %%
#Import libraries
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split
from sklearn import set_config
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter
import seaborn as sns
sns.set_style('white')
import pandas as pd
import numpy as np
## Filter ALL warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## **Load and Inspect Data**

# %%
# Importing Data:
df = pd.read_csv('/content/drive/MyDrive/Data/sales_predictions.csv')

# %%
# Gathering parameters:
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
# Display index, columns, null count, and data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
# Display the number of rows and columns
df.shape
print(f'There are {df.shape[0]} rows, and {df.shape[1]} columns')
print(f'The rows represent {df.shape[0]} observations, and the columns represent {df.shape[1]-1} features and 1 target variable.')
# Out:
# There are 8523 rows, and 12 columns
# The rows represent 8523 observations, and the columns represent 11 features and 1 target variable.

# %% [markdown]
# ## **Clean Data**

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %% [markdown]
# - #### All other data types are as they should be.

# %% [markdown]
# ## Duplicated Data

# %%
# Let's search for duplicated data:
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are no duplicated data to drop.

# %% [markdown]
# ## Missing Data

# %%
# Let's search for missing data:
df.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# - #### Identifying of missing data yields Weight (1463) and Size (2410) have missing data. Let's identifiy the percentage that is missing.

# %%
df.isna().sum() / len(df) * 100
# Out:
# Item_Identifier               0.000000
# Item_Weight                  17.165317
# Item_Fat_Content              0.000000
# Item_Visibility               0.000000
# Item_Type                     0.000000
# Item_MRP                      0.000000
# Outlet_Identifier             0.000000
# Outlet_Establishment_Year     0.000000
# Outlet_Size                  28.276428
# Outlet_Location_Type          0.000000
# Outlet_Type                   0.000000
# Item_Outlet_Sales             0.000000
# dtype: float64

# %% [markdown]
# - #### Both Weight (17%) and Size (28%) have missing data and it would be best to drop these rows.

# %% [markdown]
# - **Missing 17.17% and 28.28% of values**
# - **Strategy:**
#  - Replace missing values with the median value of the column
# - **Justification**
#   - This is less affected by outliers than strategy = 'mean'.
#   - However, for the Outlet_size, we can use the most frequented value.

# %%
# Define the Item_Weight Mean.
median_Weight = df['Item_Weight'].median()

# %%
## Replace the missing values with the column's 'median' value.
df['Item_Weight'].fillna(value = median_Weight, inplace = True)

# %%
# Let's check out the Item_Weight column for missing data.
df.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
## And we will fill in the missing Outlet_Size data with "Unknown"
df['Outlet_Size'] = df['Outlet_Size'].fillna(value = 'Unknown')

# %%
# Now let's look for missing data.
df.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %% [markdown]
# - #### We can confirm that now, there is no missing data.

# %% [markdown]
# ## Fixing Data Types

# %% [markdown]
# ## Inspecting Categorical Columns & Addressing Inconsistent Values

# %% [markdown]
# - #### We will now address the data types and make sure that they match the data dictionary.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                8523 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                8523 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
from scipy.sparse import data
# Create a series of the datatypes
data_types = df.dtypes
# Create a filter to select only the object datatypes
object_data_types = data_types[(data_types == 'object')]
# Display the series of object datatypes
object_data_types
# Out:
# Item_Identifier         object
# Item_Fat_Content        object
# Item_Type               object
# Outlet_Identifier       object
# Outlet_Size             object
# Outlet_Location_Type    object
# Outlet_Type             object
# dtype: object

# %%
## Loop through the object datatype columns
for column in object_data_types.index:
    ## Print the column name
    print(column)
    ## Print the unique values from the column
    print(df[column].unique())
    ## Print a blank row
    print('\n')
# Out:
# Item_Identifier
# ['FDA15' 'DRC01' 'FDN15' ... 'NCF55' 'NCW30' 'NCW05']
#
#
# Item_Fat_Content
# ['Low Fat' 'Regular' 'low fat' 'LF' 'reg']
#
#
# Item_Type
# ['Dairy' 'Soft Drinks' 'Meat' 'Fruits and Vegetables' 'Household'
#  'Baking Goods' 'Snack Foods' 'Frozen Foods' 'Breakfast'
#  'Health and Hygiene' 'Hard Drinks' 'Canned' 'Breads' 'Starchy Foods'
#  'Others' 'Seafood']
#
#
# Outlet_Identifier
# ['OUT049' 'OUT018' 'OUT010' 'OUT013' 'OUT027' 'OUT045' 'OUT017' 'OUT046'
#  'OUT035' 'OUT019']
#
#
# Outlet_Size
# ['Medium' 'Unknown' 'High' 'Small']
#
#
# Outlet_Location_Type
# ['Tier 1' 'Tier 3' 'Tier 2']
#
#
# Outlet_Type
# ['Supermarket Type1' 'Supermarket Type2' 'Grocery Store'
#  'Supermarket Type3']

# %%
# Let's see what issues lie in the Item_Fat_Content label.
pd.set_option('display.max_rows', None)
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5089
# Regular    2889
# LF          316
# reg         117
# low fat     112
# Name: Item_Fat_Content, dtype: int64

# %% [markdown]
# - #### Upon further investigating, "Item_Fat_Content" has inconsistant categories of data. Let's clean that up.

# %%
df['Item_Fat_Content'] = df['Item_Fat_Content'].replace('LF','Low Fat')
df['Item_Fat_Content'] = df['Item_Fat_Content'].replace('reg','Regular')
df['Item_Fat_Content'] = df['Item_Fat_Content'].replace('low fat','Low Fat')

# %% [markdown]
# - #### And let's confirm it was changed.

# %%
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64

# %%
data_types = df.dtypes
str_cols = data_types[data_types=='object'].index
str_cols
# Out:
# Index(['Item_Identifier', 'Item_Fat_Content', 'Item_Type', 'Outlet_Identifier',
#        'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type'],
#       dtype='object')

# %%
for col in str_cols:
    print(f'- {col}:')
    print(df[col].value_counts(dropna=False))
    print("\n\n")
# Out:
# - Item_Identifier:
# FDW13    10
# FDG33    10
# NCY18     9
# FDD38     9
# DRE49     9
# FDV60     9
# NCQ06     9
# FDF52     9
# FDX04     9
# NCJ30     9
# FDV38     9
# NCF42     9
# FDT07     9
# FDW26     9
# NCL31     9
# FDU12     9
# FDG09     9
# FDQ40     9
# FDX20     9
# NCI54     9
# FDX31     9
# FDP25     9
# FDW49     9
# FDF56     9
# FDO19     9
# DRN47     9
# NCB18     9
# FDE11     8
# NCX05     8
# FDQ39     8
# FDT55     8
# FDO32     8
# FDT40     8
# FDZ20     8
# FDH27     8
# FDY49     8
# FDS33     8
# FDR04     8
# FDR43     8
# FDR59     8
# FDJ55     8
# FDT24     8
# FDY55     8
# FDV09     8
# FDU23     8
# FDY47     8
# DRD25     8
# FDK58     8
# FDL58     8
# FDX58     8
# FDR44     8
# FDP28     8
# FDA39     8
# FDH28     8
# DRF27     8
# FDX21     8
# FDY56     8
# FDF05     8
# FDL20     8
# FDY03     8
# NCK05     8
# FDS55     8
# DRA59     8
# FDG24     8
# NCE54     8
# FDZ21     8
# FDA04     8
# FDW24     8
# FDT49     8
# DRF23     8
# FDD05     8
# FDH10     8
# FDX50     8
# FDT32     8
# FDK20     8
# FDU13     8
# FDN56     8
# FDZ26     8
# FDL34     8
# DRF01     8
# FDG38     8
# NCE31     8
# NCL53     8
# NCB31     8
# NCQ05     8
# FDT21     8
# NCV06     8
# DRJ24     8
# FDI41     8
# FDO52     8
# FDW14     3
# FDT47     3
# FDN20     3
# NCT53     3
# DRC49     3
# FDS39     3
# NCU29     3
# NCP14     3
# FDY09     3
# FDM14     3
# FDI05     3
# FDS22     3
# FDN51     3
# FDV56     3
# NCX17     3
# FDU16     3
# NCF55     3
# FDA14     3
# NCQ02     3
# DRM11     3
# FDV58     3
# FDL25     3
# FDV55     3
# FDP01     3
# FDG14     3
# FDQ22     3
# FDD23     3
# FDC37     3
# DRJ35     3
# FDJ40     3
# FDS51     3
# DRG39     3
# FDK46     3
# FDW22     3
# FDU47     3
# FDA51     3
# FDP36     3
# FDR16     3
# FDV27     3
# FDT38     3
# FDW15     3
# FDL15     3
# NCL42     3
# FDY58     3
# DRF51     3
# NCK31     3
# FDC56     3
# FDS08     3
# FDY32     3
# FDF02     3
# FDP51     3
# FDO51     3
# FDI53     3
# FDH52     3
# FDA57     3
# FDX28     3
# FDJ50     3
# FDQ04     3
# NCM18     3
# NCB07     3
# FDW60     3
# FDF28     3
# FDU48     3
# FDZ34     3
# FDZ19     3
# NCE55     3
# FDU03     3
# FDW04     3
# NCQ29     3
# FDZ37     3
# NCF06     3
# FDF58     3
# FDA37     3
# NCD30     3
# DRJ37     3
# FDF17     3
# FDM40     3
# FDU60     3
# FDN50     3
# NCR42     3
# NCV42     3
# NCZ05     3
# FDR13     3
# FDA58     3
# DRB01     3
# FDF50     3
# FDU56     3
# FDT44     3
# DRH59     3
# FDV14     3
# FDI10     3
# FDA22     3
# FDW37     3
# NCG55     3
# FDR39     3
# FDV31     3
# FDD32     3
# FDM12     3
# NCL54     3
# FDR40     3
# FDY46     3
# FDI35     3
# FDE21     3
# NCW30     2
# FDD22     2
# DRG25     2
# FDB10     2
# FDI36     2
# FDP15     2
# FDA48     2
# FDG28     2
# FDU43     2
# FDE38     2
# FDT33     2
# FDM16     2
# NCV18     2
# FDR57     2
# FDF38     2
# FDW58     2
# DRE01     2
# NCG19     2
# FDM38     2
# NCX53     2
# FDD48     2
# FDH22     2
# FDB47     2
# FDW10     2
# DRI59     2
# FDR03     2
# DRL59     2
# FDZ50     2
# DRC24     2
# NCC55     2
# FDE39     2
# FDU09     2
# NCS41     2
# NCW05     2
# NCM42     2
# FDK57     1
# FDN52     1
# FDT35     1
# FDE52     1
# FDY43     1
# FDQ60     1
# FDO33     1
# DRF48     1
# FDC23     1
# Name: Item_Identifier, dtype: int64
#
#
#
# - Item_Fat_Content:
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64
#
#
#
# - Item_Type:
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64
#
#
#
# - Outlet_Identifier:
# OUT027    935
# OUT013    932
# OUT049    930
# OUT046    930
# OUT035    930
# OUT045    929
# OUT018    928
# OUT017    926
# OUT010    555
# OUT019    528
# Name: Outlet_Identifier, dtype: int64
#
#
#
# - Outlet_Size:
# Medium     2793
# Unknown    2410
# Small      2388
# High        932
# Name: Outlet_Size, dtype: int64
#
#
#
# - Outlet_Location_Type:
# Tier 3    3350
# Tier 2    2785
# Tier 1    2388
# Name: Outlet_Location_Type, dtype: int64
#
#
#
# - Outlet_Type:
# Supermarket Type1    5577
# Grocery Store        1083
# Supermarket Type3     935
# Supermarket Type2     928
# Name: Outlet_Type, dtype: int64

# %% [markdown]
# - #### After further investigation of the categorical columns, there are zero inconsistencies with spelling or grammar of any categories.

# %% [markdown]
# ### 'Item Identifier' Column

# %%
## Display the unique values from the column
print(df['Item_Identifier'].unique())
# Out:
# ['FDA15' 'DRC01' 'FDN15' ... 'NCF55' 'NCW30' 'NCW05']

# %%
# Display Item Identifier value counts to look for any inconsistencies
df['Item_Identifier'].value_counts()
# Out:
# FDW13    10
# FDG33    10
# NCY18     9
# FDD38     9
# DRE49     9
# NCL54     3
# FDR40     3
# FDY46     3
# FDI35     3
# FDE21     3
# NCW30     2
# FDD22     2
# DRG25     2
# FDB10     2
# FDI36     2
# FDP15     2
# FDA48     2
# FDG28     2
# FDU43     2
# FDE38     2
# FDT33     2
# FDM16     2
# NCV18     2
# FDR57     2
# FDF38     2
# FDW58     2
# DRE01     2
# NCG19     2
# FDM38     2
# NCX53     2
# FDD48     2
# FDH22     2
# FDB47     2
# FDW10     2
# DRI59     2
# FDR03     2
# DRL59     2
# FDZ50     2
# DRC24     2
# NCC55     2
# FDE39     2
# FDU09     2
# NCS41     2
# NCW05     2
# NCM42     2
# FDK57     1
# FDN52     1
# FDT35     1
# FDE52     1
# FDY43     1
# FDQ60     1
# FDO33     1
# DRF48     1
# FDC23     1
# Name: Item_Identifier, dtype: int64

# %% [markdown]
# ### 'Item Type' Column

# %%
## Display the unique values from the column
print(df['Item_Type'].unique())
# Out:
# ['Dairy' 'Soft Drinks' 'Meat' 'Fruits and Vegetables' 'Household'
#  'Baking Goods' 'Snack Foods' 'Frozen Foods' 'Breakfast'
#  'Health and Hygiene' 'Hard Drinks' 'Canned' 'Breads' 'Starchy Foods'
#  'Others' 'Seafood']

# %%
# Display Item Type value counts to look for any inconsistencies
df['Item_Type'].value_counts()
# Out:
# Fruits and Vegetables    1232
# Snack Foods              1200
# Household                 910
# Frozen Foods              856
# Dairy                     682
# Canned                    649
# Baking Goods              648
# Health and Hygiene        520
# Soft Drinks               445
# Meat                      425
# Breads                    251
# Hard Drinks               214
# Others                    169
# Starchy Foods             148
# Breakfast                 110
# Seafood                    64
# Name: Item_Type, dtype: int64

# %% [markdown]
# ### 'Outlet Identifier' Column

# %%
## Display the unique values from the column
print(df['Outlet_Identifier'].unique())
# Out:
# ['OUT049' 'OUT018' 'OUT010' 'OUT013' 'OUT027' 'OUT045' 'OUT017' 'OUT046'
#  'OUT035' 'OUT019']

# %% [markdown]
# ### 'Outlet Size' Column

# %%
## Display the unique values from the column
print(df['Outlet_Size'].unique())
# Out:
# ['Medium' 'Unknown' 'High' 'Small']

# %% [markdown]
# ### 'Outlet Location Type' Column

# %%
## Display the unique values from the column
print(df['Outlet_Location_Type'].unique())
# Out:
# ['Tier 1' 'Tier 3' 'Tier 2']

# %% [markdown]
# ###'Outlet Type' Column

# %%
## Display the unique values from the column
print(df['Outlet_Type'].unique())
# Out:
# ['Supermarket Type1' 'Supermarket Type2' 'Grocery Store'
#  'Supermarket Type3']

# %% [markdown]
# ## Summary Statistics for Numeric Features

# %%
## Display the descriptive statistics for the numeric columns
df.describe(include= 'number')
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count   8523.00000      8523.000000  8523.000000                8523.000000
# mean      12.81342         0.066132   140.992782                1997.831867
# std        4.22724         0.051598    62.275067                   8.371760
# min        4.55500         0.000000    31.290000                1985.000000
# 25%        9.31000         0.026989    93.826500                1987.000000
# 50%       12.60000         0.053931   143.012800                1999.000000
# 75%       16.00000         0.094585   185.643700                2004.000000
# max       21.35000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %% [markdown]
# ### 'Item Weight' Column

# %%
#Display Item Weight summary statistics
df['Item_Weight'].describe()
# Out:
# count    8523.00000
# mean       12.81342
# std         4.22724
# min         4.55500
# 25%         9.31000
# 50%        12.60000
# 75%        16.00000
# max        21.35000
# Name: Item_Weight, dtype: float64

# %% [markdown]
# 'Item Visibility' Column

# %%
#Display Item Visibility summary statistics
df['Item_Visibility'].describe()
# Out:
# count    8523.000000
# mean        0.066132
# std         0.051598
# min         0.000000
# 25%         0.026989
# 50%         0.053931
# 75%         0.094585
# max         0.328391
# Name: Item_Visibility, dtype: float64

# %% [markdown]
# ### 'Item MRP' Column

# %%
#Display Item MRP summary statistics
df['Item_MRP'].describe()
# Out:
# count    8523.000000
# mean      140.992782
# std        62.275067
# min        31.290000
# 25%        93.826500
# 50%       143.012800
# 75%       185.643700
# max       266.888400
# Name: Item_MRP, dtype: float64

# %% [markdown]
# ### 'Item Outlet Sales' Column

# %%
# Display Item Outlet Sales summary statistics
df['Item_Outlet_Sales'].describe()
# Out:
# count     8523.000000
# mean      2181.288914
# std       1706.499616
# min         33.290000
# 25%        834.247400
# 50%       1794.331000
# 75%       3101.296400
# max      13086.964800
# Name: Item_Outlet_Sales, dtype: float64

# %% [markdown]
# ## **Exploratory Data Analysis**

# %% [markdown]
# ### Exploratory Visuals & Analysis
#
# - #### To help illustrate the Production Sale data, we will produce visual aides in the form of charts.
#
#  - Histogram to view the distributions of various features in your dataset.
#  - Boxplot to view statistical summaries of various features in your dataset.
#  - Heatmap of the correlation between features.

# %%
# Checking info again before we proceed.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                8523 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                8523 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
#  - For each numeric feature, we will plot the distribution and a boxplot.

# %%
# Let's find out what those numeric featurs are:
num_cols = df.select_dtypes('number').columns
num_cols
# Out:
# Index(['Item_Weight', 'Item_Visibility', 'Item_MRP',
#        'Outlet_Establishment_Year', 'Item_Outlet_Sales'],
#       dtype='object')

# %% [markdown]
# ### 'Item Weight' Column

# %%
#Display the descriptive statistics for the column
df['Item_Weight'].describe()
# Out:
# count    8523.00000
# mean       12.81342
# std         4.22724
# min         4.55500
# 25%         9.31000
# 50%        12.60000
# 75%        16.00000
# max        21.35000
# Name: Item_Weight, dtype: float64

# %% [markdown]
#  - Look at that! Going over "Item Weight", we can see that both the Mean (12.81342) and the Median (12.60000) weights are about equal.

# %% [markdown]
# ## **Exploratory Data Analysis**

# %%
## Using kind='box'
ax = df['Item_Weight'].plot(kind='box')

## Set the Title
ax.set_title('Item_Weight');

# %%
sns.heatmap(df.corr(),annot=True,cmap='Blues')
# Out:
# <Axes: >

# %% [markdown]
# ### 'Item Visibility' Boxplot

# %%
## Define a MatplotLib ax object using seaborn.boxplot()
# Use x = for horizontal
ax = sns.boxplot(data = df,
                 x = 'Item_Visibility')
ax.set_xlabel('Item Visibility', fontsize=14, weight='bold')
plt.xticks(fontsize=10, weight='bold');

# %% [markdown]
# #### Since our end goal is to increase sales, let's produce a few charts that will help us to see the properties of products, and trends, that play a crucial role for the company.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                8523 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                8523 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# ## **Explanatory Data Analysis**
#
# #### **Q1: Does MRP correlate to Sales?**
# - What two variables can we use to visualize this data?
#  - Item MRP vs Item Outlet Sales
#
# #### **Q2: Does Fat Content increase or decrease sales?**
# - What two variables can we use to visualize this data?
#  - Item_Fat_Content vs Item Outlet Sales
#
# #### **Q3: What is the trend for earnings for the last 3 years?**
# - What two variables can we use to visualize this data?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                8523 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                8523 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# #### **Q1: Does MRP correlate to Sales?**

# %%
means = df.groupby('Item_Identifier')['Item_MRP'].mean().sort_values(ascending=False)
means
# Out:
# Item_Identifier
# FDR25    265.468400
# NCS29    265.455067
# FDK51    265.416971
# FDS13    265.302686
# FDL58    263.956800
# FDI15    263.938400
# FDV49    263.855933
# FDB15    263.813943
# NCM05    263.622600
# FDY14    263.547600
# FDU12    263.445689
# FDK40    263.219571
# NCB31    263.091000
# DRF51     37.383933
# FDG22     37.069000
# NCI31     36.776143
# FDS40     36.747571
# FDU15     36.736533
# NCC55     36.434800
# DRN35     36.369867
# FDP12     36.227400
# NCA06     36.090429
# DRF25     35.990429
# FDT36     35.770733
# NCY41     35.496057
# FDX10     35.462400
# NCY05     35.427400
# FDE59     35.369867
# NCL41     35.088267
# NCN53     35.001686
# FDT02     34.787400
# NCF55     34.687400
# FDV16     34.512943
# NCE31     34.471600
# FDJ45     34.450171
# NCO06     34.272467
# FDQ47     34.207400
# FDU21     34.127229
# FDV28     33.998657
# NCR42     33.690000
# FDX59     33.655800
# FDG40     32.980800
# DRK12     32.315000
# Name: Item_MRP, dtype: float64

# %%
## Define a MatplotLib ax object using sns.regplot()
ax = sns.regplot(x ='Item_MRP', y = 'Item_Outlet_Sales', data = df, line_kws = {'color':'red'})
plt.xticks(fontsize=10, weight='bold')
plt.yticks(fontsize=10, weight='bold')
## Set the Title
ax.set_title('Item Outlet Sales vs Item MRP', fontsize=16, weight='bold')
# Set Axes Labels
ax.set_xlabel('Item MRP', fontsize=14, weight='bold')
ax.set_ylabel('Item Outlet Sales', fontsize=14, weight='bold')
price_fmt = StrMethodFormatter(" ₹ {x:,.0f}")
ax.yaxis.set_major_formatter(price_fmt)
plt.show()

# %% [markdown]
# #### **Q2: Does Fat Content increase or decrease sales?**

# %%
means2 = df.groupby('Item_Fat_Content')['Item_Outlet_Sales'].mean().sort_values(ascending=False)
means2
# Out:
# Item_Fat_Content
# Regular    2224.561170
# Low Fat    2157.711534
# Name: Item_Outlet_Sales, dtype: float64

# %%
## Define a MatplotLib ax object using sns.regplot()

ax = sns.regplot(x ='Item_Weight', y = 'Item_Outlet_Sales', data = df, line_kws = {'color':'red'})

plt.xticks(fontsize=10, weight='bold')
plt.yticks(fontsize=10, weight='bold')

## Set the Title
ax.set_title('Item Outlet Sales vs Item Weight',  fontsize=16, weight='bold')
# Set Axes Labels
ax.set_xlabel('Item Weight', fontsize=14, weight='bold')
ax.set_ylabel('Item Outlet Sales', fontsize=14, weight='bold')
price_fmt = StrMethodFormatter(" ₹ {x:,.0f}")
ax.yaxis.set_major_formatter(price_fmt)
plt.show()

# %% [markdown]
# #### **Q3: Which Item type has the most sales?**

# %%
df['Item_Type'].value_counts(normalize=True)
# Out:
# Fruits and Vegetables    0.144550
# Snack Foods              0.140795
# Household                0.106770
# Frozen Foods             0.100434
# Dairy                    0.080019
# Canned                   0.076147
# Baking Goods             0.076030
# Health and Hygiene       0.061011
# Soft Drinks              0.052212
# Meat                     0.049865
# Breads                   0.029450
# Hard Drinks              0.025109
# Others                   0.019829
# Starchy Foods            0.017365
# Breakfast                0.012906
# Seafood                  0.007509
# Name: Item_Type, dtype: float64

# %%
# Set Color palette
   
df_sorted = df.groupby('Item_Type')['Item_Outlet_Sales'].sum().reset_index().sort_values('Item_Outlet_Sales', ascending=False)
colors = sns.color_palette("mako_r", n_colors=len(df_sorted))
plt.figure(figsize=(12, 6))
ax = sns.barplot(data=df_sorted,
                 x='Item_Outlet_Sales',
                 y='Item_Type', 
                 order=df_sorted['Item_Type'], 
                 palette=colors)
ax.set_ylabel('Item Type', fontsize=14, weight='bold')
ax.set_xlabel('Item Outlet Sales', fontsize=14, weight='bold')
ax.set_title('Total Sales by Item Type', fontsize=16, weight='bold')
plt.xticks(fontsize=10, weight='bold')
plt.yticks(fontsize=10, weight='bold')
price_fmt = StrMethodFormatter(" ₹ {x:,.0f}")
ax.xaxis.set_major_formatter(price_fmt)
plt.tight_layout()

# %% [markdown]
# #### Preprocessing for Machine Learning

# %% [markdown]
# #### Imports

# %%
# Importing Data:
df2 = pd.read_csv('/content/drive/MyDrive/Data/sales_predictions.csv')

# %% [markdown]
# ### Reloading the Data

# %%
df2.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %% [markdown]
# ### Performing Preprocessing Steps

# %% [markdown]
# Fixing Errors

# %%
# Replace LF to 0, low fat to 0, Low Fat to 0, Regular to 1, reg to 1 in Item Fat Content column
# Replace LF to Low Fat, low fat to Low Fat, reg to Regular in Item Fat Content column
df['Item_Fat_Content'].replace({'LF': 'Low Fat', 'low fat': 'Low Fat', 'reg': 'Regular'}, inplace=True)

# %%
#Check value counts
df['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64

# %% [markdown]
#  - We have no column to drop.

# %%
# Checking for Duplicates
df2.duplicated().sum()
# Out:
# 0

# %% [markdown]
#  - We have no duplicates.

# %%
# Checking missing values
df2.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
# Redoing what was done far above.
i_mean = np.mean(df["Item_Weight"])
# replacing missing values with Item_Weight average
df2['Item_Weight'].fillna(value = i_mean, inplace = True)
# filling in missing data in the Outlet_Size solumn
df2['Outlet_Size'].fillna(value = "Unknown", inplace = True)
# double checking to see if the missing data has been filled in Outlet_Size
df2.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                8523 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                8523 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# #### Defining X and y

# %%
#Defining my Target variable which is y and the remaining features X
X = df.drop(columns = ['Item_Outlet_Sales'])
y = df['Item_Outlet_Sales']

# %% [markdown]
# #### Train-Test-Split

# %%
# Perfoming a train-test-split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6392 entries, 4776 to 7270
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            6392 non-null   object
#  1   Item_Weight                6392 non-null   float64
#  2   Item_Fat_Content           6392 non-null   object
#  3   Item_Visibility            6392 non-null   float64
#  4   Item_Type                  6392 non-null   object
#  5   Item_MRP                   6392 non-null   float64
#  6   Outlet_Identifier          6392 non-null   object
#  7   Outlet_Establishment_Year  6392 non-null   int64
#  8   Outlet_Size                6392 non-null   object
#  9   Outlet_Location_Type       6392 non-null   object
#  10  Outlet_Type                6392 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 599.2+ KB

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2131 entries, 7503 to 1784
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            2131 non-null   object
#  1   Item_Weight                2131 non-null   float64
#  2   Item_Fat_Content           2131 non-null   object
#  3   Item_Visibility            2131 non-null   float64
#  4   Item_Type                  2131 non-null   object
#  5   Item_MRP                   2131 non-null   float64
#  6   Outlet_Identifier          2131 non-null   object
#  7   Outlet_Establishment_Year  2131 non-null   int64
#  8   Outlet_Size                2131 non-null   object
#  9   Outlet_Location_Type       2131 non-null   object
#  10  Outlet_Type                2131 non-null   object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 199.8+ KB

# %% [markdown]
# ### Preparing Data

# %% [markdown]
# ### Column Selectors

# %%
# Selectors
cat_selector = make_column_selector(dtype_include='object')
num_selector = make_column_selector(dtype_include='number')

# %% [markdown]
# ### Transformers

# %%
# Imputers
freq_imputer = SimpleImputer(strategy='most_frequent')
median_imputer = SimpleImputer(strategy='median')
# Scaler
scaler = StandardScaler()
# One-hot encoder
ohe = OneHotEncoder(handle_unknown='ignore', sparse=False)

# %% [markdown]
# #### Making a Preprocessing Pipeline

# %%
# Numeric pipeline
numeric_pipe = make_pipeline(median_imputer, scaler)
numeric_pipe
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='median')),
#                 ('standardscaler', StandardScaler())])

# %%
# Categorical pipeline
categorical_pipe = make_pipeline(freq_imputer, ohe)
categorical_pipe
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='most_frequent')),
#                 ('onehotencoder',
#                  OneHotEncoder(handle_unknown='ignore', sparse=False))])

# %%
# Tuples for Column Transformer
number_tuple = (numeric_pipe, num_selector)
category_tuple = (categorical_pipe, cat_selector)

# ColumnTransformer
preprocessor = make_column_transformer(number_tuple, category_tuple, remainder='passthrough', verbose_feature_names_out=False)
preprocessor
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('pipeline-1',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7fd6b42e9450>),
#                                 ('pipeline-2',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7fd6b42ebb20>)],
#                   verbose_feature_names_out=False)

# %% [markdown]
# ## Maching Learning - Training the Models

# %% [markdown]
# ### Imports for Machine Learning

# %%
# Imports
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
preprocessor
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('pipeline-1',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7fd6b42e9450>),
#                                 ('pipeline-2',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7fd6b42ebb20>)],
#                   verbose_feature_names_out=False)

# %% [markdown]
# ### Data Fitting and Scaler

# %%
# fit on train
preprocessor.fit(X_train)
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('pipeline-1',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('standardscaler',
#                                                   StandardScaler())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7fd6b42e9450>),
#                                 ('pipeline-2',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x7fd6b42ebb20>)],
#                   verbose_feature_names_out=False)

# %%
# transform train and test
X_train_processed = preprocessor.transform(X_train)
X_test_processed = preprocessor.transform(X_test)

# %%
# Check for missing values and that data is scaled and one-hot encoded
X_train_processed
# Out:
# array([[ 0.82944552, -0.71277507,  1.82810922, ...,  0.        ,
#          1.        ,  0.        ],
#        [ 0.5686337 , -1.29105225,  0.60336888, ...,  0.        ,
#          1.        ,  0.        ],
#        [-0.11896108,  1.81331864,  0.24454056, ...,  1.        ,
#          0.        ,  0.        ],
#        ...,
#        [ 1.12582258, -0.92052713,  1.52302674, ...,  1.        ,
#          0.        ,  0.        ],
#        [ 1.77785212, -0.2277552 , -0.38377708, ...,  1.        ,
#          0.        ,  0.        ],
#        [ 0.82944552, -0.95867683, -0.73836105, ...,  1.        ,
#          0.        ,  0.        ]])

# %%
#Check for missing values and that data is scaled and one-hot encoded#print(np.isnan(X_train_processed).sum().sum(), 'missing values in training data')
print(np.isnan(X_test_processed).sum().sum(), 'missing values in testing data')
print('\n')
print('All data in X_train_processed are', X_train_processed.dtype)
print('All data in X_test_processed are', X_test_processed.dtype)
print('\n')
print('shape of data is', X_train_processed.shape)
print('\n')
X_train_processed
# Out:
# 0 missing values in testing data
#
#
# All data in X_train_processed are float64
# All data in X_test_processed are float64
#
#
# shape of data is (6392, 1593)
# array([[ 0.82944552, -0.71277507,  1.82810922, ...,  0.        ,
#          1.        ,  0.        ],
#        [ 0.5686337 , -1.29105225,  0.60336888, ...,  0.        ,
#          1.        ,  0.        ],
#        [-0.11896108,  1.81331864,  0.24454056, ...,  1.        ,
#          0.        ,  0.        ],
#        ...,
#        [ 1.12582258, -0.92052713,  1.52302674, ...,  1.        ,
#          0.        ,  0.        ],
#        [ 1.77785212, -0.2277552 , -0.38377708, ...,  1.        ,
#          0.        ,  0.        ],
#        [ 0.82944552, -0.95867683, -0.73836105, ...,  1.        ,
#          0.        ,  0.        ]])

# %% [markdown]
# ### Convert Preprocessed Array to Dataframes

# %%
# Create dataframes from the processed arrays
# First get column names
cols = preprocessor.get_feature_names_out()

# %%
X_train_processed_df = pd.DataFrame(X_train_processed, 
                          columns = cols,
                          index = X_train.index)

X_test_processed_df = pd.DataFrame(X_test_processed, 
                         columns = cols,
                         index = X_test.index)

# %%
cols
# Out:
# array(['Item_Weight', 'Item_Visibility', 'Item_MRP', ...,
#        'Outlet_Type_Supermarket Type1', 'Outlet_Type_Supermarket Type2',
#        'Outlet_Type_Supermarket Type3'], dtype=object)

# %%
#Check for missing values and that data is scaled and one-hot encoded#print(np.isnan(X_train_processed).sum().sum(), 'missing values in training data')
print(np.isnan(X_test_processed).sum().sum(), 'missing values in testing data')
print('\n')
print('All data in X_train_processed are', X_train_processed.dtype)
print('All data in X_test_processed are', X_test_processed.dtype)
print('\n')
print('shape of data is', X_train_processed.shape)
print('\n')
# Check the data types
print(f'\nThe datatypes are {X_train_processed_df.dtypes}')
X_train_processed
# Out:
# 0 missing values in testing data
#
#
# All data in X_train_processed are float64
# All data in X_test_processed are float64
#
#
# shape of data is (6392, 1593)
#
#
#
# The datatypes are Item_Weight                        float64
# Item_Visibility                    float64
# Item_MRP                           float64
# Outlet_Establishment_Year          float64
# Item_Identifier_DRA12              float64
# Item_Identifier_DRA24              float64
# Item_Identifier_DRA59              float64
# Item_Identifier_DRB01              float64
# Item_Identifier_DRB13              float64
# Item_Identifier_DRB24              float64
# Item_Identifier_DRB25              float64
# Item_Identifier_DRB48              float64
# Item_Identifier_DRC01              float64
# Item_Identifier_DRC12              float64
# Item_Identifier_DRC13              float64
# Item_Identifier_DRC25              float64
# Item_Identifier_DRC27              float64
# Item_Identifier_DRC36              float64
# Item_Identifier_DRC49              float64
# Item_Identifier_DRD01              float64
# Item_Identifier_DRD12              float64
# Item_Identifier_DRD13              float64
# Item_Identifier_DRD15              float64
# Item_Identifier_DRD24              float64
# Item_Identifier_DRD25              float64
# Item_Identifier_DRD27              float64
# Item_Identifier_DRD37              float64
# Item_Identifier_DRD49              float64
# Item_Identifier_DRD60              float64
# Item_Identifier_DRE01              float64
# Item_Identifier_DRE03              float64
# Item_Identifier_DRE12              float64
# Item_Identifier_DRE13              float64
# Item_Identifier_DRE15              float64
# Item_Identifier_DRE25              float64
# Item_Identifier_DRE27              float64
# Item_Identifier_DRE37              float64
# Item_Identifier_DRE48              float64
# Item_Identifier_DRE49              float64
# Item_Identifier_DRE60              float64
# Item_Identifier_DRF01              float64
# Item_Identifier_DRF03              float64
# Item_Identifier_DRF13              float64
# Item_Identifier_DRF15              float64
# Item_Identifier_DRF23              float64
# Item_Identifier_DRF25              float64
# Item_Identifier_DRF27              float64
# Item_Identifier_DRF36              float64
# Item_Identifier_DRF37              float64
# Item_Identifier_DRF48              float64
# Item_Identifier_DRF49              float64
# Item_Identifier_DRF51              float64
# Item_Identifier_DRF60              float64
# Item_Identifier_DRG01              float64
# Item_Identifier_DRG03              float64
# Item_Identifier_DRG11              float64
# Item_Identifier_DRG13              float64
# Item_Identifier_DRG15              float64
# Item_Identifier_DRG23              float64
# Item_Identifier_DRG25              float64
# Item_Identifier_DRG27              float64
# Item_Identifier_DRG36              float64
# Item_Identifier_DRG37              float64
# Item_Identifier_DRG39              float64
# Item_Identifier_DRG48              float64
# Item_Identifier_DRG49              float64
# Item_Identifier_DRG51              float64
# Item_Identifier_DRH01              float64
# Item_Identifier_DRH03              float64
# Item_Identifier_DRH11              float64
# Item_Identifier_DRH13              float64
# Item_Identifier_DRH15              float64
# Item_Identifier_DRH23              float64
# Item_Identifier_DRH25              float64
# Item_Identifier_DRH36              float64
# Item_Identifier_DRH37              float64
# Item_Identifier_DRH39              float64
# Item_Identifier_DRH49              float64
# Item_Identifier_DRH51              float64
# Item_Identifier_DRH59              float64
# Item_Identifier_DRI01              float64
# Item_Identifier_DRI03              float64
# Item_Identifier_DRI11              float64
# Item_Identifier_DRI13              float64
# Item_Identifier_DRI23              float64
# Item_Identifier_DRI25              float64
# Item_Identifier_DRI37              float64
# Item_Identifier_DRI39              float64
# Item_Identifier_DRI47              float64
# Item_Identifier_DRI49              float64
# Item_Identifier_DRI51              float64
# Item_Identifier_DRI59              float64
# Item_Identifier_DRJ01              float64
# Item_Identifier_DRJ11              float64
# Item_Identifier_DRJ13              float64
# Item_Identifier_DRJ23              float64
# Item_Identifier_DRJ24              float64
# Item_Identifier_DRJ25              float64
# Item_Identifier_DRJ35              float64
# Item_Identifier_DRJ37              float64
# Item_Identifier_DRJ39              float64
# Item_Identifier_DRJ47              float64
# Item_Identifier_DRJ49              float64
# Item_Identifier_DRJ51              float64
# Item_Identifier_DRJ59              float64
# Item_Identifier_DRK01              float64
# Item_Identifier_DRK11              float64
# Item_Identifier_DRK12              float64
# Item_Identifier_DRK13              float64
# Item_Identifier_DRK23              float64
# Item_Identifier_DRK35              float64
# Item_Identifier_DRK37              float64
# Item_Identifier_DRK39              float64
# Item_Identifier_DRK47              float64
# Item_Identifier_DRK49              float64
# Item_Identifier_DRK59              float64
# Item_Identifier_DRL01              float64
# Item_Identifier_DRL11              float64
# Item_Identifier_DRL23              float64
# Item_Identifier_DRL35              float64
# Item_Identifier_DRL37              float64
# Item_Identifier_DRL47              float64
# Item_Identifier_DRL49              float64
# Item_Identifier_DRL59              float64
# Item_Identifier_DRL60              float64
# Item_Identifier_DRM11              float64
# Item_Identifier_DRM23              float64
# Item_Identifier_DRM35              float64
# Item_Identifier_DRM37              float64
# Item_Identifier_DRM47              float64
# Item_Identifier_DRM48              float64
# Item_Identifier_DRM49              float64
# Item_Identifier_DRM59              float64
# Item_Identifier_DRN11              float64
# Item_Identifier_DRN35              float64
# Item_Identifier_DRN36              float64
# Item_Identifier_DRN37              float64
# Item_Identifier_DRN47              float64
# Item_Identifier_DRN59              float64
# Item_Identifier_DRO35              float64
# Item_Identifier_DRO47              float64
# Item_Identifier_DRO59              float64
# Item_Identifier_DRP35              float64
# Item_Identifier_DRP47              float64
# Item_Identifier_DRQ35              float64
# Item_Identifier_DRY23              float64
# Item_Identifier_DRZ11              float64
# Item_Identifier_DRZ24              float64
# Item_Identifier_FDA01              float64
# Item_Identifier_FDA02              float64
# Item_Identifier_FDA03              float64
# Item_Identifier_FDA04              float64
# Item_Identifier_FDA07              float64
# Item_Identifier_FDA08              float64
# Item_Identifier_FDA09              float64
# Item_Identifier_FDA10              float64
# Item_Identifier_FDA11              float64
# Item_Identifier_FDA13              float64
# Item_Identifier_FDA14              float64
# Item_Identifier_FDA15              float64
# Item_Identifier_FDA16              float64
# Item_Identifier_FDA19              float64
# Item_Identifier_FDA20              float64
# Item_Identifier_FDA21              float64
# Item_Identifier_FDA22              float64
# Item_Identifier_FDA23              float64
# Item_Identifier_FDA25              float64
# Item_Identifier_FDA26              float64
# Item_Identifier_FDA27              float64
# Item_Identifier_FDA28              float64
# Item_Identifier_FDA31              float64
# Item_Identifier_FDA32              float64
# Item_Identifier_FDA33              float64
# Item_Identifier_FDA34              float64
# Item_Identifier_FDA35              float64
# Item_Identifier_FDA36              float64
# Item_Identifier_FDA37              float64
# Item_Identifier_FDA38              float64
# Item_Identifier_FDA39              float64
# Item_Identifier_FDA40              float64
# Item_Identifier_FDA43              float64
# Item_Identifier_FDA44              float64
# Item_Identifier_FDA45              float64
# Item_Identifier_FDA46              float64
# Item_Identifier_FDA47              float64
# Item_Identifier_FDA48              float64
# Item_Identifier_FDA49              float64
# Item_Identifier_FDA50              float64
# Item_Identifier_FDA51              float64
# Item_Identifier_FDA52              float64
# Item_Identifier_FDA55              float64
# Item_Identifier_FDA56              float64
# Item_Identifier_FDA57              float64
# Item_Identifier_FDA58              float64
# Item_Identifier_FDB02              float64
# Item_Identifier_FDB03              float64
# Item_Identifier_FDB04              float64
# Item_Identifier_FDB05              float64
# Item_Identifier_FDB08              float64
# Item_Identifier_FDB09              float64
# Item_Identifier_FDB10              float64
# Item_Identifier_FDB11              float64
# Item_Identifier_FDB12              float64
# Item_Identifier_FDB14              float64
# Item_Identifier_FDB15              float64
# Item_Identifier_FDB16              float64
# Item_Identifier_FDB17              float64
# Item_Identifier_FDB20              float64
# Item_Identifier_FDB21              float64
# Item_Identifier_FDB22              float64
# Item_Identifier_FDB23              float64
# Item_Identifier_FDB26              float64
# Item_Identifier_FDB27              float64
# Item_Identifier_FDB28              float64
# Item_Identifier_FDB29              float64
# Item_Identifier_FDB32              float64
# Item_Identifier_FDB33              float64
# Item_Identifier_FDB34              float64
# Item_Identifier_FDB35              float64
# Item_Identifier_FDB36              float64
# Item_Identifier_FDB37              float64
# Item_Identifier_FDB38              float64
# Item_Identifier_FDB39              float64
# Item_Identifier_FDB40              float64
# Item_Identifier_FDB41              float64
# Item_Identifier_FDB44              float64
# Item_Identifier_FDB45              float64
# Item_Identifier_FDB46              float64
# Item_Identifier_FDB47              float64
# Item_Identifier_FDB49              float64
# Item_Identifier_FDB50              float64
# Item_Identifier_FDB51              float64
# Item_Identifier_FDB52              float64
# Item_Identifier_FDB53              float64
# Item_Identifier_FDB56              float64
# Item_Identifier_FDB57              float64
# Item_Identifier_FDB58              float64
# Item_Identifier_FDB59              float64
# Item_Identifier_FDB60              float64
# Item_Identifier_FDC02              float64
# Item_Identifier_FDC03              float64
# Item_Identifier_FDC04              float64
# Item_Identifier_FDC05              float64
# Item_Identifier_FDC08              float64
# Item_Identifier_FDC09              float64
# Item_Identifier_FDC10              float64
# Item_Identifier_FDC11              float64
# Item_Identifier_FDC14              float64
# Item_Identifier_FDC15              float64
# Item_Identifier_FDC16              float64
# Item_Identifier_FDC17              float64
# Item_Identifier_FDC20              float64
# Item_Identifier_FDC21              float64
# Item_Identifier_FDC22              float64
# Item_Identifier_FDC26              float64
# Item_Identifier_FDC29              float64
# Item_Identifier_FDC32              float64
# Item_Identifier_FDC33              float64
# Item_Identifier_FDC34              float64
# Item_Identifier_FDC35              float64
# Item_Identifier_FDC37              float64
# Item_Identifier_FDC38              float64
# Item_Identifier_FDC39              float64
# Item_Identifier_FDC40              float64
# Item_Identifier_FDC41              float64
# Item_Identifier_FDC44              float64
# Item_Identifier_FDC45              float64
# Item_Identifier_FDC46              float64
# Item_Identifier_FDC47              float64
# Item_Identifier_FDC48              float64
# Item_Identifier_FDC50              float64
# Item_Identifier_FDC51              float64
# Item_Identifier_FDC52              float64
# Item_Identifier_FDC53              float64
# Item_Identifier_FDC56              float64
# Item_Identifier_FDC57              float64
# Item_Identifier_FDC58              float64
# Item_Identifier_FDC59              float64
# Item_Identifier_FDC60              float64
# Item_Identifier_FDD02              float64
# Item_Identifier_FDD03              float64
# Item_Identifier_FDD04              float64
# Item_Identifier_FDD05              float64
# Item_Identifier_FDD08              float64
# Item_Identifier_FDD09              float64
# Item_Identifier_FDD10              float64
# Item_Identifier_FDD11              float64
# Item_Identifier_FDD14              float64
# Item_Identifier_FDD16              float64
# Item_Identifier_FDD17              float64
# Item_Identifier_FDD20              float64
# Item_Identifier_FDD21              float64
# Item_Identifier_FDD22              float64
# Item_Identifier_FDD23              float64
# Item_Identifier_FDD26              float64
# Item_Identifier_FDD28              float64
# Item_Identifier_FDD29              float64
# Item_Identifier_FDD32              float64
# Item_Identifier_FDD33              float64
# Item_Identifier_FDD34              float64
# Item_Identifier_FDD35              float64
# Item_Identifier_FDD36              float64
# Item_Identifier_FDD38              float64
# Item_Identifier_FDD39              float64
# Item_Identifier_FDD40              float64
# Item_Identifier_FDD41              float64
# Item_Identifier_FDD44              float64
# Item_Identifier_FDD45              float64
# Item_Identifier_FDD46              float64
# Item_Identifier_FDD47              float64
# Item_Identifier_FDD48              float64
# Item_Identifier_FDD50              float64
# Item_Identifier_FDD51              float64
# Item_Identifier_FDD52              float64
# Item_Identifier_FDD53              float64
# Item_Identifier_FDD56              float64
# Item_Identifier_FDD57              float64
# Item_Identifier_FDD58              float64
# Item_Identifier_FDD59              float64
# Item_Identifier_FDE02              float64
# Item_Identifier_FDE04              float64
# Item_Identifier_FDE05              float64
# Item_Identifier_FDE08              float64
# Item_Identifier_FDE09              float64
# Item_Identifier_FDE10              float64
# Item_Identifier_FDE11              float64
# Item_Identifier_FDE14              float64
# Item_Identifier_FDE16              float64
# Item_Identifier_FDE17              float64
# Item_Identifier_FDE20              float64
# Item_Identifier_FDE21              float64
# Item_Identifier_FDE22              float64
# Item_Identifier_FDE23              float64
# Item_Identifier_FDE24              float64
# Item_Identifier_FDE26              float64
# Item_Identifier_FDE28              float64
# Item_Identifier_FDE29              float64
# Item_Identifier_FDE32              float64
# Item_Identifier_FDE33              float64
# Item_Identifier_FDE34              float64
# Item_Identifier_FDE35              float64
# Item_Identifier_FDE36              float64
# Item_Identifier_FDE38              float64
# Item_Identifier_FDE39              float64
# Item_Identifier_FDE40              float64
# Item_Identifier_FDE41              float64
# Item_Identifier_FDE44              float64
# Item_Identifier_FDE45              float64
# Item_Identifier_FDE46              float64
# Item_Identifier_FDE47              float64
# Item_Identifier_FDE50              float64
# Item_Identifier_FDE51              float64
# Item_Identifier_FDE52              float64
# Item_Identifier_FDE53              float64
# Item_Identifier_FDE56              float64
# Item_Identifier_FDE57              float64
# Item_Identifier_FDE58              float64
# Item_Identifier_FDE59              float64
# Item_Identifier_FDF02              float64
# Item_Identifier_FDF04              float64
# Item_Identifier_FDF05              float64
# Item_Identifier_FDF08              float64
# Item_Identifier_FDF09              float64
# Item_Identifier_FDF10              float64
# Item_Identifier_FDF11              float64
# Item_Identifier_FDF12              float64
# Item_Identifier_FDF14              float64
# Item_Identifier_FDF16              float64
# Item_Identifier_FDF17              float64
# Item_Identifier_FDF20              float64
# Item_Identifier_FDF21              float64
# Item_Identifier_FDF22              float64
# Item_Identifier_FDF24              float64
# Item_Identifier_FDF26              float64
# Item_Identifier_FDF28              float64
# Item_Identifier_FDF29              float64
# Item_Identifier_FDF32              float64
# Item_Identifier_FDF33              float64
# Item_Identifier_FDF34              float64
# Item_Identifier_FDF35              float64
# Item_Identifier_FDF38              float64
# Item_Identifier_FDF39              float64
# Item_Identifier_FDF40              float64
# Item_Identifier_FDF41              float64
# Item_Identifier_FDF44              float64
# Item_Identifier_FDF45              float64
# Item_Identifier_FDF46              float64
# Item_Identifier_FDF47              float64
# Item_Identifier_FDF50              float64
# Item_Identifier_FDF52              float64
# Item_Identifier_FDF53              float64
# Item_Identifier_FDF56              float64
# Item_Identifier_FDF57              float64
# Item_Identifier_FDF58              float64
# Item_Identifier_FDF59              float64
# Item_Identifier_FDG02              float64
# Item_Identifier_FDG04              float64
# Item_Identifier_FDG05              float64
# Item_Identifier_FDG08              float64
# Item_Identifier_FDG09              float64
# Item_Identifier_FDG10              float64
# Item_Identifier_FDG12              float64
# Item_Identifier_FDG14              float64
# Item_Identifier_FDG16              float64
# Item_Identifier_FDG17              float64
# Item_Identifier_FDG20              float64
# Item_Identifier_FDG21              float64
# Item_Identifier_FDG22              float64
# Item_Identifier_FDG24              float64
# Item_Identifier_FDG26              float64
# Item_Identifier_FDG28              float64
# Item_Identifier_FDG29              float64
# Item_Identifier_FDG31              float64
# Item_Identifier_FDG32              float64
# Item_Identifier_FDG33              float64
# Item_Identifier_FDG34              float64
# Item_Identifier_FDG35              float64
# Item_Identifier_FDG38              float64
# Item_Identifier_FDG40              float64
# Item_Identifier_FDG41              float64
# Item_Identifier_FDG44              float64
# Item_Identifier_FDG45              float64
# Item_Identifier_FDG46              float64
# Item_Identifier_FDG47              float64
# Item_Identifier_FDG50              float64
# Item_Identifier_FDG52              float64
# Item_Identifier_FDG53              float64
# Item_Identifier_FDG56              float64
# Item_Identifier_FDG57              float64
# Item_Identifier_FDG58              float64
# Item_Identifier_FDG59              float64
# Item_Identifier_FDG60              float64
# Item_Identifier_FDH02              float64
# Item_Identifier_FDH04              float64
# Item_Identifier_FDH05              float64
# Item_Identifier_FDH08              float64
# Item_Identifier_FDH09              float64
# Item_Identifier_FDH10              float64
# Item_Identifier_FDH12              float64
# Item_Identifier_FDH14              float64
# Item_Identifier_FDH16              float64
# Item_Identifier_FDH17              float64
# Item_Identifier_FDH19              float64
# Item_Identifier_FDH20              float64
# Item_Identifier_FDH21              float64
# Item_Identifier_FDH22              float64
# Item_Identifier_FDH24              float64
# Item_Identifier_FDH26              float64
# Item_Identifier_FDH27              float64
# Item_Identifier_FDH28              float64
# Item_Identifier_FDH31              float64
# Item_Identifier_FDH32              float64
# Item_Identifier_FDH33              float64
# Item_Identifier_FDH34              float64
# Item_Identifier_FDH35              float64
# Item_Identifier_FDH38              float64
# Item_Identifier_FDH40              float64
# Item_Identifier_FDH41              float64
# Item_Identifier_FDH44              float64
# Item_Identifier_FDH45              float64
# Item_Identifier_FDH46              float64
# Item_Identifier_FDH47              float64
# Item_Identifier_FDH48              float64
# Item_Identifier_FDH50              float64
# Item_Identifier_FDH52              float64
# Item_Identifier_FDH53              float64
# Item_Identifier_FDH56              float64
# Item_Identifier_FDH57              float64
# Item_Identifier_FDH58              float64
# Item_Identifier_FDH60              float64
# Item_Identifier_FDI02              float64
# Item_Identifier_FDI04              float64
# Item_Identifier_FDI05              float64
# Item_Identifier_FDI07              float64
# Item_Identifier_FDI08              float64
# Item_Identifier_FDI09              float64
# Item_Identifier_FDI10              float64
# Item_Identifier_FDI12              float64
# Item_Identifier_FDI14              float64
# Item_Identifier_FDI15              float64
# Item_Identifier_FDI16              float64
# Item_Identifier_FDI19              float64
# Item_Identifier_FDI20              float64
# Item_Identifier_FDI21              float64
# Item_Identifier_FDI22              float64
# Item_Identifier_FDI24              float64
# Item_Identifier_FDI26              float64
# Item_Identifier_FDI27              float64
# Item_Identifier_FDI28              float64
# Item_Identifier_FDI32              float64
# Item_Identifier_FDI33              float64
# Item_Identifier_FDI34              float64
# Item_Identifier_FDI35              float64
# Item_Identifier_FDI36              float64
# Item_Identifier_FDI38              float64
# Item_Identifier_FDI40              float64
# Item_Identifier_FDI41              float64
# Item_Identifier_FDI44              float64
# Item_Identifier_FDI45              float64
# Item_Identifier_FDI46              float64
# Item_Identifier_FDI48              float64
# Item_Identifier_FDI50              float64
# Item_Identifier_FDI52              float64
# Item_Identifier_FDI53              float64
# Item_Identifier_FDI56              float64
# Item_Identifier_FDI57              float64
# Item_Identifier_FDI58              float64
# Item_Identifier_FDI60              float64
# Item_Identifier_FDJ02              float64
# Item_Identifier_FDJ03              float64
# Item_Identifier_FDJ04              float64
# Item_Identifier_FDJ07              float64
# Item_Identifier_FDJ08              float64
# Item_Identifier_FDJ09              float64
# Item_Identifier_FDJ10              float64
# Item_Identifier_FDJ12              float64
# Item_Identifier_FDJ14              float64
# Item_Identifier_FDJ15              float64
# Item_Identifier_FDJ16              float64
# Item_Identifier_FDJ20              float64
# Item_Identifier_FDJ21              float64
# Item_Identifier_FDJ22              float64
# Item_Identifier_FDJ26              float64
# Item_Identifier_FDJ27              float64
# Item_Identifier_FDJ28              float64
# Item_Identifier_FDJ32              float64
# Item_Identifier_FDJ33              float64
# Item_Identifier_FDJ34              float64
# Item_Identifier_FDJ36              float64
# Item_Identifier_FDJ38              float64
# Item_Identifier_FDJ40              float64
# Item_Identifier_FDJ41              float64
# Item_Identifier_FDJ44              float64
# Item_Identifier_FDJ45              float64
# Item_Identifier_FDJ46              float64
# Item_Identifier_FDJ48              float64
# Item_Identifier_FDJ50              float64
# Item_Identifier_FDJ52              float64
# Item_Identifier_FDJ53              float64
# Item_Identifier_FDJ55              float64
# Item_Identifier_FDJ56              float64
# Item_Identifier_FDJ57              float64
# Item_Identifier_FDJ58              float64
# Item_Identifier_FDJ60              float64
# Item_Identifier_FDK02              float64
# Item_Identifier_FDK03              float64
# Item_Identifier_FDK04              float64
# Item_Identifier_FDK08              float64
# Item_Identifier_FDK09              float64
# Item_Identifier_FDK10              float64
# Item_Identifier_FDK14              float64
# Item_Identifier_FDK15              float64
# Item_Identifier_FDK16              float64
# Item_Identifier_FDK20              float64
# Item_Identifier_FDK21              float64
# Item_Identifier_FDK22              float64
# Item_Identifier_FDK24              float64
# Item_Identifier_FDK25              float64
# Item_Identifier_FDK26              float64
# Item_Identifier_FDK27              float64
# Item_Identifier_FDK28              float64
# Item_Identifier_FDK32              float64
# Item_Identifier_FDK33              float64
# Item_Identifier_FDK34              float64
# Item_Identifier_FDK36              float64
# Item_Identifier_FDK38              float64
# Item_Identifier_FDK40              float64
# Item_Identifier_FDK41              float64
# Item_Identifier_FDK43              float64
# Item_Identifier_FDK44              float64
# Item_Identifier_FDK45              float64
# Item_Identifier_FDK46              float64
# Item_Identifier_FDK48              float64
# Item_Identifier_FDK50              float64
# Item_Identifier_FDK51              float64
# Item_Identifier_FDK52              float64
# Item_Identifier_FDK55              float64
# Item_Identifier_FDK56              float64
# Item_Identifier_FDK58              float64
# Item_Identifier_FDK60              float64
# Item_Identifier_FDL02              float64
# Item_Identifier_FDL03              float64
# Item_Identifier_FDL04              float64
# Item_Identifier_FDL08              float64
# Item_Identifier_FDL09              float64
# Item_Identifier_FDL10              float64
# Item_Identifier_FDL12              float64
# Item_Identifier_FDL13              float64
# Item_Identifier_FDL14              float64
# Item_Identifier_FDL15              float64
# Item_Identifier_FDL16              float64
# Item_Identifier_FDL20              float64
# Item_Identifier_FDL21              float64
# Item_Identifier_FDL22              float64
# Item_Identifier_FDL24              float64
# Item_Identifier_FDL25              float64
# Item_Identifier_FDL26              float64
# Item_Identifier_FDL27              float64
# Item_Identifier_FDL28              float64
# Item_Identifier_FDL32              float64
# Item_Identifier_FDL33              float64
# Item_Identifier_FDL34              float64
# Item_Identifier_FDL36              float64
# Item_Identifier_FDL38              float64
# Item_Identifier_FDL39              float64
# Item_Identifier_FDL40              float64
# Item_Identifier_FDL43              float64
# Item_Identifier_FDL44              float64
# Item_Identifier_FDL45              float64
# Item_Identifier_FDL46              float64
# Item_Identifier_FDL48              float64
# Item_Identifier_FDL50              float64
# Item_Identifier_FDL51              float64
# Item_Identifier_FDL52              float64
# Item_Identifier_FDL56              float64
# Item_Identifier_FDL57              float64
# Item_Identifier_FDL58              float64
# Item_Identifier_FDM01              float64
# Item_Identifier_FDM02              float64
# Item_Identifier_FDM03              float64
# Item_Identifier_FDM04              float64
# Item_Identifier_FDM08              float64
# Item_Identifier_FDM09              float64
# Item_Identifier_FDM10              float64
# Item_Identifier_FDM12              float64
# Item_Identifier_FDM13              float64
# Item_Identifier_FDM14              float64
# Item_Identifier_FDM15              float64
# Item_Identifier_FDM20              float64
# Item_Identifier_FDM21              float64
# Item_Identifier_FDM22              float64
# Item_Identifier_FDM24              float64
# Item_Identifier_FDM25              float64
# Item_Identifier_FDM27              float64
# Item_Identifier_FDM28              float64
# Item_Identifier_FDM32              float64
# Item_Identifier_FDM33              float64
# Item_Identifier_FDM34              float64
# Item_Identifier_FDM36              float64
# Item_Identifier_FDM38              float64
# Item_Identifier_FDM39              float64
# Item_Identifier_FDM40              float64
# Item_Identifier_FDM44              float64
# Item_Identifier_FDM45              float64
# Item_Identifier_FDM46              float64
# Item_Identifier_FDM50              float64
# Item_Identifier_FDM51              float64
# Item_Identifier_FDM52              float64
# Item_Identifier_FDM56              float64
# Item_Identifier_FDM57              float64
# Item_Identifier_FDM58              float64
# Item_Identifier_FDM60              float64
# Item_Identifier_FDN01              float64
# Item_Identifier_FDN02              float64
# Item_Identifier_FDN03              float64
# Item_Identifier_FDN04              float64
# Item_Identifier_FDN08              float64
# Item_Identifier_FDN09              float64
# Item_Identifier_FDN10              float64
# Item_Identifier_FDN12              float64
# Item_Identifier_FDN13              float64
# Item_Identifier_FDN15              float64
# Item_Identifier_FDN16              float64
# Item_Identifier_FDN20              float64
# Item_Identifier_FDN21              float64
# Item_Identifier_FDN22              float64
# Item_Identifier_FDN23              float64
# Item_Identifier_FDN24              float64
# Item_Identifier_FDN25              float64
# Item_Identifier_FDN27              float64
# Item_Identifier_FDN28              float64
# Item_Identifier_FDN31              float64
# Item_Identifier_FDN32              float64
# Item_Identifier_FDN33              float64
# Item_Identifier_FDN34              float64
# Item_Identifier_FDN38              float64
# Item_Identifier_FDN39              float64
# Item_Identifier_FDN40              float64
# Item_Identifier_FDN44              float64
# Item_Identifier_FDN45              float64
# Item_Identifier_FDN46              float64
# Item_Identifier_FDN48              float64
# Item_Identifier_FDN49              float64
# Item_Identifier_FDN50              float64
# Item_Identifier_FDN51              float64
# Item_Identifier_FDN56              float64
# Item_Identifier_FDN57              float64
# Item_Identifier_FDN58              float64
# Item_Identifier_FDN60              float64
# Item_Identifier_FDO01              float64
# Item_Identifier_FDO03              float64
# Item_Identifier_FDO04              float64
# Item_Identifier_FDO08              float64
# Item_Identifier_FDO09              float64
# Item_Identifier_FDO10              float64
# Item_Identifier_FDO11              float64
# Item_Identifier_FDO12              float64
# Item_Identifier_FDO13              float64
# Item_Identifier_FDO15              float64
# Item_Identifier_FDO16              float64
# Item_Identifier_FDO19              float64
# Item_Identifier_FDO20              float64
# Item_Identifier_FDO21              float64
# Item_Identifier_FDO22              float64
# Item_Identifier_FDO23              float64
# Item_Identifier_FDO24              float64
# Item_Identifier_FDO25              float64
# Item_Identifier_FDO27              float64
# Item_Identifier_FDO28              float64
# Item_Identifier_FDO31              float64
# Item_Identifier_FDO32              float64
# Item_Identifier_FDO33              float64
# Item_Identifier_FDO34              float64
# Item_Identifier_FDO36              float64
# Item_Identifier_FDO37              float64
# Item_Identifier_FDO38              float64
# Item_Identifier_FDO39              float64
# Item_Identifier_FDO40              float64
# Item_Identifier_FDO44              float64
# Item_Identifier_FDO45              float64
# Item_Identifier_FDO46              float64
# Item_Identifier_FDO48              float64
# Item_Identifier_FDO49              float64
# Item_Identifier_FDO50              float64
# Item_Identifier_FDO51              float64
# Item_Identifier_FDO52              float64
# Item_Identifier_FDO56              float64
# Item_Identifier_FDO57              float64
# Item_Identifier_FDO58              float64
# Item_Identifier_FDO60              float64
# Item_Identifier_FDP01              float64
# Item_Identifier_FDP03              float64
# Item_Identifier_FDP04              float64
# Item_Identifier_FDP07              float64
# Item_Identifier_FDP08              float64
# Item_Identifier_FDP09              float64
# Item_Identifier_FDP10              float64
# Item_Identifier_FDP11              float64
# Item_Identifier_FDP12              float64
# Item_Identifier_FDP13              float64
# Item_Identifier_FDP15              float64
# Item_Identifier_FDP16              float64
# Item_Identifier_FDP19              float64
# Item_Identifier_FDP20              float64
# Item_Identifier_FDP21              float64
# Item_Identifier_FDP22              float64
# Item_Identifier_FDP23              float64
# Item_Identifier_FDP24              float64
# Item_Identifier_FDP25              float64
# Item_Identifier_FDP26              float64
# Item_Identifier_FDP27              float64
# Item_Identifier_FDP28              float64
# Item_Identifier_FDP31              float64
# Item_Identifier_FDP32              float64
# Item_Identifier_FDP33              float64
# Item_Identifier_FDP34              float64
# Item_Identifier_FDP36              float64
# Item_Identifier_FDP37              float64
# Item_Identifier_FDP38              float64
# Item_Identifier_FDP39              float64
# Item_Identifier_FDP40              float64
# Item_Identifier_FDP44              float64
# Item_Identifier_FDP45              float64
# Item_Identifier_FDP46              float64
# Item_Identifier_FDP48              float64
# Item_Identifier_FDP49              float64
# Item_Identifier_FDP51              float64
# Item_Identifier_FDP52              float64
# Item_Identifier_FDP56              float64
# Item_Identifier_FDP57              float64
# Item_Identifier_FDP58              float64
# Item_Identifier_FDP59              float64
# Item_Identifier_FDP60              float64
# Item_Identifier_FDQ01              float64
# Item_Identifier_FDQ03              float64
# Item_Identifier_FDQ04              float64
# Item_Identifier_FDQ07              float64
# Item_Identifier_FDQ08              float64
# Item_Identifier_FDQ09              float64
# Item_Identifier_FDQ10              float64
# Item_Identifier_FDQ11              float64
# Item_Identifier_FDQ12              float64
# Item_Identifier_FDQ13              float64
# Item_Identifier_FDQ14              float64
# Item_Identifier_FDQ15              float64
# Item_Identifier_FDQ16              float64
# Item_Identifier_FDQ19              float64
# Item_Identifier_FDQ20              float64
# Item_Identifier_FDQ21              float64
# Item_Identifier_FDQ22              float64
# Item_Identifier_FDQ23              float64
# Item_Identifier_FDQ24              float64
# Item_Identifier_FDQ25              float64
# Item_Identifier_FDQ26              float64
# Item_Identifier_FDQ27              float64
# Item_Identifier_FDQ28              float64
# Item_Identifier_FDQ31              float64
# Item_Identifier_FDQ32              float64
# Item_Identifier_FDQ33              float64
# Item_Identifier_FDQ34              float64
# Item_Identifier_FDQ36              float64
# Item_Identifier_FDQ37              float64
# Item_Identifier_FDQ39              float64
# Item_Identifier_FDQ40              float64
# Item_Identifier_FDQ44              float64
# Item_Identifier_FDQ45              float64
# Item_Identifier_FDQ46              float64
# Item_Identifier_FDQ47              float64
# Item_Identifier_FDQ48              float64
# Item_Identifier_FDQ49              float64
# Item_Identifier_FDQ51              float64
# Item_Identifier_FDQ52              float64
# Item_Identifier_FDQ55              float64
# Item_Identifier_FDQ56              float64
# Item_Identifier_FDQ57              float64
# Item_Identifier_FDQ58              float64
# Item_Identifier_FDQ59              float64
# Item_Identifier_FDQ60              float64
# Item_Identifier_FDR01              float64
# Item_Identifier_FDR02              float64
# Item_Identifier_FDR03              float64
# Item_Identifier_FDR04              float64
# Item_Identifier_FDR07              float64
# Item_Identifier_FDR08              float64
# Item_Identifier_FDR09              float64
# Item_Identifier_FDR10              float64
# Item_Identifier_FDR11              float64
# Item_Identifier_FDR12              float64
# Item_Identifier_FDR13              float64
# Item_Identifier_FDR14              float64
# Item_Identifier_FDR15              float64
# Item_Identifier_FDR16              float64
# Item_Identifier_FDR19              float64
# Item_Identifier_FDR20              float64
# Item_Identifier_FDR21              float64
# Item_Identifier_FDR22              float64
# Item_Identifier_FDR23              float64
# Item_Identifier_FDR24              float64
# Item_Identifier_FDR25              float64
# Item_Identifier_FDR26              float64
# Item_Identifier_FDR27              float64
# Item_Identifier_FDR28              float64
# Item_Identifier_FDR31              float64
# Item_Identifier_FDR32              float64
# Item_Identifier_FDR33              float64
# Item_Identifier_FDR34              float64
# Item_Identifier_FDR35              float64
# Item_Identifier_FDR36              float64
# Item_Identifier_FDR37              float64
# Item_Identifier_FDR39              float64
# Item_Identifier_FDR40              float64
# Item_Identifier_FDR43              float64
# Item_Identifier_FDR44              float64
# Item_Identifier_FDR45              float64
# Item_Identifier_FDR46              float64
# Item_Identifier_FDR47              float64
# Item_Identifier_FDR48              float64
# Item_Identifier_FDR49              float64
# Item_Identifier_FDR51              float64
# Item_Identifier_FDR52              float64
# Item_Identifier_FDR55              float64
# Item_Identifier_FDR56              float64
# Item_Identifier_FDR57              float64
# Item_Identifier_FDR58              float64
# Item_Identifier_FDR59              float64
# Item_Identifier_FDR60              float64
# Item_Identifier_FDS01              float64
# Item_Identifier_FDS02              float64
# Item_Identifier_FDS03              float64
# Item_Identifier_FDS04              float64
# Item_Identifier_FDS07              float64
# Item_Identifier_FDS08              float64
# Item_Identifier_FDS09              float64
# Item_Identifier_FDS10              float64
# Item_Identifier_FDS11              float64
# Item_Identifier_FDS12              float64
# Item_Identifier_FDS13              float64
# Item_Identifier_FDS14              float64
# Item_Identifier_FDS15              float64
# Item_Identifier_FDS16              float64
# Item_Identifier_FDS19              float64
# Item_Identifier_FDS20              float64
# Item_Identifier_FDS21              float64
# Item_Identifier_FDS22              float64
# Item_Identifier_FDS23              float64
# Item_Identifier_FDS24              float64
# Item_Identifier_FDS25              float64
# Item_Identifier_FDS26              float64
# Item_Identifier_FDS27              float64
# Item_Identifier_FDS28              float64
# Item_Identifier_FDS31              float64
# Item_Identifier_FDS32              float64
# Item_Identifier_FDS33              float64
# Item_Identifier_FDS34              float64
# Item_Identifier_FDS35              float64
# Item_Identifier_FDS36              float64
# Item_Identifier_FDS37              float64
# Item_Identifier_FDS39              float64
# Item_Identifier_FDS40              float64
# Item_Identifier_FDS43              float64
# Item_Identifier_FDS44              float64
# Item_Identifier_FDS45              float64
# Item_Identifier_FDS46              float64
# Item_Identifier_FDS47              float64
# Item_Identifier_FDS48              float64
# Item_Identifier_FDS49              float64
# Item_Identifier_FDS50              float64
# Item_Identifier_FDS51              float64
# Item_Identifier_FDS52              float64
# Item_Identifier_FDS55              float64
# Item_Identifier_FDS56              float64
# Item_Identifier_FDS57              float64
# Item_Identifier_FDS58              float64
# Item_Identifier_FDS59              float64
# Item_Identifier_FDS60              float64
# Item_Identifier_FDT01              float64
# Item_Identifier_FDT02              float64
# Item_Identifier_FDT03              float64
# Item_Identifier_FDT04              float64
# Item_Identifier_FDT07              float64
# Item_Identifier_FDT08              float64
# Item_Identifier_FDT09              float64
# Item_Identifier_FDT10              float64
# Item_Identifier_FDT11              float64
# Item_Identifier_FDT12              float64
# Item_Identifier_FDT13              float64
# Item_Identifier_FDT14              float64
# Item_Identifier_FDT15              float64
# Item_Identifier_FDT16              float64
# Item_Identifier_FDT19              float64
# Item_Identifier_FDT20              float64
# Item_Identifier_FDT21              float64
# Item_Identifier_FDT22              float64
# Item_Identifier_FDT23              float64
# Item_Identifier_FDT24              float64
# Item_Identifier_FDT25              float64
# Item_Identifier_FDT26              float64
# Item_Identifier_FDT27              float64
# Item_Identifier_FDT28              float64
# Item_Identifier_FDT31              float64
# Item_Identifier_FDT32              float64
# Item_Identifier_FDT33              float64
# Item_Identifier_FDT34              float64
# Item_Identifier_FDT35              float64
# Item_Identifier_FDT36              float64
# Item_Identifier_FDT37              float64
# Item_Identifier_FDT39              float64
# Item_Identifier_FDT40              float64
# Item_Identifier_FDT43              float64
# Item_Identifier_FDT44              float64
# Item_Identifier_FDT45              float64
# Item_Identifier_FDT46              float64
# Item_Identifier_FDT47              float64
# Item_Identifier_FDT48              float64
# Item_Identifier_FDT49              float64
# Item_Identifier_FDT50              float64
# Item_Identifier_FDT51              float64
# Item_Identifier_FDT52              float64
# Item_Identifier_FDT55              float64
# Item_Identifier_FDT56              float64
# Item_Identifier_FDT57              float64
# Item_Identifier_FDT58              float64
# Item_Identifier_FDT59              float64
# Item_Identifier_FDT60              float64
# Item_Identifier_FDU01              float64
# Item_Identifier_FDU02              float64
# Item_Identifier_FDU03              float64
# Item_Identifier_FDU04              float64
# Item_Identifier_FDU07              float64
# Item_Identifier_FDU08              float64
# Item_Identifier_FDU09              float64
# Item_Identifier_FDU10              float64
# Item_Identifier_FDU11              float64
# Item_Identifier_FDU12              float64
# Item_Identifier_FDU13              float64
# Item_Identifier_FDU14              float64
# Item_Identifier_FDU15              float64
# Item_Identifier_FDU16              float64
# Item_Identifier_FDU19              float64
# Item_Identifier_FDU20              float64
# Item_Identifier_FDU21              float64
# Item_Identifier_FDU22              float64
# Item_Identifier_FDU23              float64
# Item_Identifier_FDU24              float64
# Item_Identifier_FDU25              float64
# Item_Identifier_FDU26              float64
# Item_Identifier_FDU27              float64
# Item_Identifier_FDU28              float64
# Item_Identifier_FDU31              float64
# Item_Identifier_FDU32              float64
# Item_Identifier_FDU33              float64
# Item_Identifier_FDU34              float64
# Item_Identifier_FDU35              float64
# Item_Identifier_FDU36              float64
# Item_Identifier_FDU37              float64
# Item_Identifier_FDU38              float64
# Item_Identifier_FDU39              float64
# Item_Identifier_FDU40              float64
# Item_Identifier_FDU43              float64
# Item_Identifier_FDU44              float64
# Item_Identifier_FDU45              float64
# Item_Identifier_FDU46              float64
# Item_Identifier_FDU47              float64
# Item_Identifier_FDU48              float64
# Item_Identifier_FDU49              float64
# Item_Identifier_FDU50              float64
# Item_Identifier_FDU51              float64
# Item_Identifier_FDU52              float64
# Item_Identifier_FDU55              float64
# Item_Identifier_FDU56              float64
# Item_Identifier_FDU57              float64
# Item_Identifier_FDU58              float64
# Item_Identifier_FDU59              float64
# Item_Identifier_FDU60              float64
# Item_Identifier_FDV01              float64
# Item_Identifier_FDV02              float64
# Item_Identifier_FDV03              float64
# Item_Identifier_FDV04              float64
# Item_Identifier_FDV07              float64
# Item_Identifier_FDV08              float64
# Item_Identifier_FDV09              float64
# Item_Identifier_FDV10              float64
# Item_Identifier_FDV11              float64
# Item_Identifier_FDV12              float64
# Item_Identifier_FDV13              float64
# Item_Identifier_FDV14              float64
# Item_Identifier_FDV15              float64
# Item_Identifier_FDV16              float64
# Item_Identifier_FDV19              float64
# Item_Identifier_FDV20              float64
# Item_Identifier_FDV21              float64
# Item_Identifier_FDV22              float64
# Item_Identifier_FDV23              float64
# Item_Identifier_FDV24              float64
# Item_Identifier_FDV25              float64
# Item_Identifier_FDV26              float64
# Item_Identifier_FDV27              float64
# Item_Identifier_FDV28              float64
# Item_Identifier_FDV31              float64
# Item_Identifier_FDV32              float64
# Item_Identifier_FDV33              float64
# Item_Identifier_FDV34              float64
# Item_Identifier_FDV35              float64
# Item_Identifier_FDV36              float64
# Item_Identifier_FDV37              float64
# Item_Identifier_FDV38              float64
# Item_Identifier_FDV39              float64
# Item_Identifier_FDV40              float64
# Item_Identifier_FDV43              float64
# Item_Identifier_FDV44              float64
# Item_Identifier_FDV45              float64
# Item_Identifier_FDV46              float64
# Item_Identifier_FDV47              float64
# Item_Identifier_FDV48              float64
# Item_Identifier_FDV49              float64
# Item_Identifier_FDV50              float64
# Item_Identifier_FDV51              float64
# Item_Identifier_FDV52              float64
# Item_Identifier_FDV55              float64
# Item_Identifier_FDV56              float64
# Item_Identifier_FDV57              float64
# Item_Identifier_FDV58              float64
# Item_Identifier_FDV59              float64
# Item_Identifier_FDV60              float64
# Item_Identifier_FDW01              float64
# Item_Identifier_FDW02              float64
# Item_Identifier_FDW03              float64
# Item_Identifier_FDW04              float64
# Item_Identifier_FDW07              float64
# Item_Identifier_FDW08              float64
# Item_Identifier_FDW09              float64
# Item_Identifier_FDW10              float64
# Item_Identifier_FDW11              float64
# Item_Identifier_FDW12              float64
# Item_Identifier_FDW13              float64
# Item_Identifier_FDW14              float64
# Item_Identifier_FDW15              float64
# Item_Identifier_FDW16              float64
# Item_Identifier_FDW19              float64
# Item_Identifier_FDW20              float64
# Item_Identifier_FDW21              float64
# Item_Identifier_FDW22              float64
# Item_Identifier_FDW23              float64
# Item_Identifier_FDW24              float64
# Item_Identifier_FDW25              float64
# Item_Identifier_FDW26              float64
# Item_Identifier_FDW27              float64
# Item_Identifier_FDW28              float64
# Item_Identifier_FDW31              float64
# Item_Identifier_FDW32              float64
# Item_Identifier_FDW33              float64
# Item_Identifier_FDW34              float64
# Item_Identifier_FDW35              float64
# Item_Identifier_FDW36              float64
# Item_Identifier_FDW37              float64
# Item_Identifier_FDW38              float64
# Item_Identifier_FDW39              float64
# Item_Identifier_FDW40              float64
# Item_Identifier_FDW43              float64
# Item_Identifier_FDW44              float64
# Item_Identifier_FDW45              float64
# Item_Identifier_FDW46              float64
# Item_Identifier_FDW47              float64
# Item_Identifier_FDW48              float64
# Item_Identifier_FDW49              float64
# Item_Identifier_FDW50              float64
# Item_Identifier_FDW51              float64
# Item_Identifier_FDW52              float64
# Item_Identifier_FDW55              float64
# Item_Identifier_FDW56              float64
# Item_Identifier_FDW57              float64
# Item_Identifier_FDW58              float64
# ...
# Item_Identifier_FDZ32              float64
# Item_Identifier_FDZ33              float64
# Item_Identifier_FDZ34              float64
# Item_Identifier_FDZ35              float64
# Item_Identifier_FDZ36              float64
# Item_Identifier_FDZ37              float64
# Item_Identifier_FDZ38              float64
# Item_Identifier_FDZ39              float64
# Item_Identifier_FDZ40              float64
# Item_Identifier_FDZ43              float64
# Item_Identifier_FDZ44              float64
# Item_Identifier_FDZ45              float64
# Item_Identifier_FDZ46              float64
# Item_Identifier_FDZ47              float64
# Item_Identifier_FDZ48              float64
# Item_Identifier_FDZ49              float64
# Item_Identifier_FDZ50              float64
# Item_Identifier_FDZ51              float64
# Item_Identifier_FDZ52              float64
# Item_Identifier_FDZ55              float64
# Item_Identifier_FDZ56              float64
# Item_Identifier_FDZ57              float64
# Item_Identifier_FDZ58              float64
# Item_Identifier_FDZ59              float64
# Item_Identifier_FDZ60              float64
# Item_Identifier_NCA05              float64
# Item_Identifier_NCA06              float64
# Item_Identifier_NCA17              float64
# Item_Identifier_NCA18              float64
# Item_Identifier_NCA29              float64
# Item_Identifier_NCA30              float64
# Item_Identifier_NCA41              float64
# Item_Identifier_NCA42              float64
# Item_Identifier_NCA53              float64
# Item_Identifier_NCA54              float64
# Item_Identifier_NCB06              float64
# Item_Identifier_NCB07              float64
# Item_Identifier_NCB18              float64
# Item_Identifier_NCB19              float64
# Item_Identifier_NCB30              float64
# Item_Identifier_NCB31              float64
# Item_Identifier_NCB42              float64
# Item_Identifier_NCB43              float64
# Item_Identifier_NCB54              float64
# Item_Identifier_NCB55              float64
# Item_Identifier_NCC06              float64
# Item_Identifier_NCC07              float64
# Item_Identifier_NCC18              float64
# Item_Identifier_NCC19              float64
# Item_Identifier_NCC30              float64
# Item_Identifier_NCC31              float64
# Item_Identifier_NCC42              float64
# Item_Identifier_NCC43              float64
# Item_Identifier_NCC54              float64
# Item_Identifier_NCD06              float64
# Item_Identifier_NCD07              float64
# Item_Identifier_NCD18              float64
# Item_Identifier_NCD19              float64
# Item_Identifier_NCD30              float64
# Item_Identifier_NCD31              float64
# Item_Identifier_NCD42              float64
# Item_Identifier_NCD43              float64
# Item_Identifier_NCD54              float64
# Item_Identifier_NCD55              float64
# Item_Identifier_NCE06              float64
# Item_Identifier_NCE07              float64
# Item_Identifier_NCE18              float64
# Item_Identifier_NCE19              float64
# Item_Identifier_NCE30              float64
# Item_Identifier_NCE31              float64
# Item_Identifier_NCE42              float64
# Item_Identifier_NCE43              float64
# Item_Identifier_NCE54              float64
# Item_Identifier_NCE55              float64
# Item_Identifier_NCF06              float64
# Item_Identifier_NCF07              float64
# Item_Identifier_NCF18              float64
# Item_Identifier_NCF19              float64
# Item_Identifier_NCF30              float64
# Item_Identifier_NCF31              float64
# Item_Identifier_NCF42              float64
# Item_Identifier_NCF43              float64
# Item_Identifier_NCF54              float64
# Item_Identifier_NCF55              float64
# Item_Identifier_NCG06              float64
# Item_Identifier_NCG07              float64
# Item_Identifier_NCG18              float64
# Item_Identifier_NCG19              float64
# Item_Identifier_NCG30              float64
# Item_Identifier_NCG42              float64
# Item_Identifier_NCG43              float64
# Item_Identifier_NCG54              float64
# Item_Identifier_NCG55              float64
# Item_Identifier_NCH06              float64
# Item_Identifier_NCH07              float64
# Item_Identifier_NCH18              float64
# Item_Identifier_NCH29              float64
# Item_Identifier_NCH30              float64
# Item_Identifier_NCH42              float64
# Item_Identifier_NCH43              float64
# Item_Identifier_NCH54              float64
# Item_Identifier_NCH55              float64
# Item_Identifier_NCI06              float64
# Item_Identifier_NCI17              float64
# Item_Identifier_NCI18              float64
# Item_Identifier_NCI29              float64
# Item_Identifier_NCI30              float64
# Item_Identifier_NCI31              float64
# Item_Identifier_NCI42              float64
# Item_Identifier_NCI43              float64
# Item_Identifier_NCI54              float64
# Item_Identifier_NCI55              float64
# Item_Identifier_NCJ05              float64
# Item_Identifier_NCJ06              float64
# Item_Identifier_NCJ17              float64
# Item_Identifier_NCJ18              float64
# Item_Identifier_NCJ19              float64
# Item_Identifier_NCJ29              float64
# Item_Identifier_NCJ30              float64
# Item_Identifier_NCJ31              float64
# Item_Identifier_NCJ42              float64
# Item_Identifier_NCJ43              float64
# Item_Identifier_NCJ54              float64
# Item_Identifier_NCK05              float64
# Item_Identifier_NCK06              float64
# Item_Identifier_NCK07              float64
# Item_Identifier_NCK17              float64
# Item_Identifier_NCK18              float64
# Item_Identifier_NCK19              float64
# Item_Identifier_NCK29              float64
# Item_Identifier_NCK30              float64
# Item_Identifier_NCK31              float64
# Item_Identifier_NCK42              float64
# Item_Identifier_NCK53              float64
# Item_Identifier_NCK54              float64
# Item_Identifier_NCL05              float64
# Item_Identifier_NCL06              float64
# Item_Identifier_NCL07              float64
# Item_Identifier_NCL17              float64
# Item_Identifier_NCL18              float64
# Item_Identifier_NCL19              float64
# Item_Identifier_NCL29              float64
# Item_Identifier_NCL30              float64
# Item_Identifier_NCL31              float64
# Item_Identifier_NCL41              float64
# Item_Identifier_NCL42              float64
# Item_Identifier_NCL53              float64
# Item_Identifier_NCL54              float64
# Item_Identifier_NCL55              float64
# Item_Identifier_NCM05              float64
# Item_Identifier_NCM06              float64
# Item_Identifier_NCM07              float64
# Item_Identifier_NCM17              float64
# Item_Identifier_NCM18              float64
# Item_Identifier_NCM19              float64
# Item_Identifier_NCM26              float64
# Item_Identifier_NCM29              float64
# Item_Identifier_NCM30              float64
# Item_Identifier_NCM31              float64
# Item_Identifier_NCM41              float64
# Item_Identifier_NCM42              float64
# Item_Identifier_NCM43              float64
# Item_Identifier_NCM53              float64
# Item_Identifier_NCM54              float64
# Item_Identifier_NCM55              float64
# Item_Identifier_NCN05              float64
# Item_Identifier_NCN06              float64
# Item_Identifier_NCN07              float64
# Item_Identifier_NCN14              float64
# Item_Identifier_NCN17              float64
# Item_Identifier_NCN18              float64
# Item_Identifier_NCN19              float64
# Item_Identifier_NCN26              float64
# Item_Identifier_NCN29              float64
# Item_Identifier_NCN30              float64
# Item_Identifier_NCN41              float64
# Item_Identifier_NCN42              float64
# Item_Identifier_NCN43              float64
# Item_Identifier_NCN53              float64
# Item_Identifier_NCN54              float64
# Item_Identifier_NCN55              float64
# Item_Identifier_NCO02              float64
# Item_Identifier_NCO05              float64
# Item_Identifier_NCO06              float64
# Item_Identifier_NCO07              float64
# Item_Identifier_NCO14              float64
# Item_Identifier_NCO17              float64
# Item_Identifier_NCO18              float64
# Item_Identifier_NCO26              float64
# Item_Identifier_NCO29              float64
# Item_Identifier_NCO30              float64
# Item_Identifier_NCO41              float64
# Item_Identifier_NCO42              float64
# Item_Identifier_NCO43              float64
# Item_Identifier_NCO53              float64
# Item_Identifier_NCO54              float64
# Item_Identifier_NCO55              float64
# Item_Identifier_NCP02              float64
# Item_Identifier_NCP05              float64
# Item_Identifier_NCP06              float64
# Item_Identifier_NCP14              float64
# Item_Identifier_NCP17              float64
# Item_Identifier_NCP18              float64
# Item_Identifier_NCP29              float64
# Item_Identifier_NCP30              float64
# Item_Identifier_NCP42              float64
# Item_Identifier_NCP43              float64
# Item_Identifier_NCP50              float64
# Item_Identifier_NCP53              float64
# Item_Identifier_NCP54              float64
# Item_Identifier_NCP55              float64
# Item_Identifier_NCQ02              float64
# Item_Identifier_NCQ05              float64
# Item_Identifier_NCQ06              float64
# Item_Identifier_NCQ17              float64
# Item_Identifier_NCQ18              float64
# Item_Identifier_NCQ29              float64
# Item_Identifier_NCQ30              float64
# Item_Identifier_NCQ38              float64
# Item_Identifier_NCQ41              float64
# Item_Identifier_NCQ42              float64
# Item_Identifier_NCQ43              float64
# Item_Identifier_NCQ50              float64
# Item_Identifier_NCQ53              float64
# Item_Identifier_NCQ54              float64
# Item_Identifier_NCR05              float64
# Item_Identifier_NCR06              float64
# Item_Identifier_NCR17              float64
# Item_Identifier_NCR18              float64
# Item_Identifier_NCR29              float64
# Item_Identifier_NCR30              float64
# Item_Identifier_NCR38              float64
# Item_Identifier_NCR41              float64
# Item_Identifier_NCR42              float64
# Item_Identifier_NCR50              float64
# Item_Identifier_NCR53              float64
# Item_Identifier_NCR54              float64
# Item_Identifier_NCS05              float64
# Item_Identifier_NCS06              float64
# Item_Identifier_NCS17              float64
# Item_Identifier_NCS18              float64
# Item_Identifier_NCS29              float64
# Item_Identifier_NCS30              float64
# Item_Identifier_NCS38              float64
# Item_Identifier_NCS41              float64
# Item_Identifier_NCS42              float64
# Item_Identifier_NCS53              float64
# Item_Identifier_NCS54              float64
# Item_Identifier_NCT05              float64
# Item_Identifier_NCT06              float64
# Item_Identifier_NCT17              float64
# Item_Identifier_NCT18              float64
# Item_Identifier_NCT29              float64
# Item_Identifier_NCT30              float64
# Item_Identifier_NCT41              float64
# Item_Identifier_NCT42              float64
# Item_Identifier_NCT53              float64
# Item_Identifier_NCT54              float64
# Item_Identifier_NCU05              float64
# Item_Identifier_NCU06              float64
# Item_Identifier_NCU17              float64
# Item_Identifier_NCU18              float64
# Item_Identifier_NCU29              float64
# Item_Identifier_NCU30              float64
# Item_Identifier_NCU41              float64
# Item_Identifier_NCU42              float64
# Item_Identifier_NCU53              float64
# Item_Identifier_NCU54              float64
# Item_Identifier_NCV05              float64
# Item_Identifier_NCV06              float64
# Item_Identifier_NCV17              float64
# Item_Identifier_NCV18              float64
# Item_Identifier_NCV29              float64
# Item_Identifier_NCV30              float64
# Item_Identifier_NCV41              float64
# Item_Identifier_NCV42              float64
# Item_Identifier_NCV53              float64
# Item_Identifier_NCV54              float64
# Item_Identifier_NCW05              float64
# Item_Identifier_NCW06              float64
# Item_Identifier_NCW17              float64
# Item_Identifier_NCW18              float64
# Item_Identifier_NCW29              float64
# Item_Identifier_NCW30              float64
# Item_Identifier_NCW41              float64
# Item_Identifier_NCW42              float64
# Item_Identifier_NCW53              float64
# Item_Identifier_NCW54              float64
# Item_Identifier_NCX05              float64
# Item_Identifier_NCX06              float64
# Item_Identifier_NCX17              float64
# Item_Identifier_NCX18              float64
# Item_Identifier_NCX29              float64
# Item_Identifier_NCX30              float64
# Item_Identifier_NCX41              float64
# Item_Identifier_NCX42              float64
# Item_Identifier_NCX53              float64
# Item_Identifier_NCX54              float64
# Item_Identifier_NCY05              float64
# Item_Identifier_NCY06              float64
# Item_Identifier_NCY17              float64
# Item_Identifier_NCY18              float64
# Item_Identifier_NCY29              float64
# Item_Identifier_NCY30              float64
# Item_Identifier_NCY41              float64
# Item_Identifier_NCY42              float64
# Item_Identifier_NCY53              float64
# Item_Identifier_NCY54              float64
# Item_Identifier_NCZ05              float64
# Item_Identifier_NCZ06              float64
# Item_Identifier_NCZ17              float64
# Item_Identifier_NCZ18              float64
# Item_Identifier_NCZ29              float64
# Item_Identifier_NCZ30              float64
# Item_Identifier_NCZ41              float64
# Item_Identifier_NCZ42              float64
# Item_Identifier_NCZ53              float64
# Item_Identifier_NCZ54              float64
# Item_Fat_Content_Low Fat           float64
# Item_Fat_Content_Regular           float64
# Item_Type_Baking Goods             float64
# Item_Type_Breads                   float64
# Item_Type_Breakfast                float64
# Item_Type_Canned                   float64
# Item_Type_Dairy                    float64
# Item_Type_Frozen Foods             float64
# Item_Type_Fruits and Vegetables    float64
# Item_Type_Hard Drinks              float64
# Item_Type_Health and Hygiene       float64
# Item_Type_Household                float64
# Item_Type_Meat                     float64
# Item_Type_Others                   float64
# Item_Type_Seafood                  float64
# Item_Type_Snack Foods              float64
# Item_Type_Soft Drinks              float64
# Item_Type_Starchy Foods            float64
# Outlet_Identifier_OUT010           float64
# Outlet_Identifier_OUT013           float64
# Outlet_Identifier_OUT017           float64
# Outlet_Identifier_OUT018           float64
# Outlet_Identifier_OUT019           float64
# Outlet_Identifier_OUT027           float64
# Outlet_Identifier_OUT035           float64
# Outlet_Identifier_OUT045           float64
# Outlet_Identifier_OUT046           float64
# Outlet_Identifier_OUT049           float64
# Outlet_Size_High                   float64
# Outlet_Size_Medium                 float64
# Outlet_Size_Small                  float64
# Outlet_Size_Unknown                float64
# Outlet_Location_Type_Tier 1        float64
# Outlet_Location_Type_Tier 2        float64
# Outlet_Location_Type_Tier 3        float64
# Outlet_Type_Grocery Store          float64
# Outlet_Type_Supermarket Type1      float64
# Outlet_Type_Supermarket Type2      float64
# Outlet_Type_Supermarket Type3      float64
# dtype: object
# array([[ 0.82944552, -0.71277507,  1.82810922, ...,  0.        ,
#          1.        ,  0.        ],
#        [ 0.5686337 , -1.29105225,  0.60336888, ...,  0.        ,
#          1.        ,  0.        ],
#        [-0.11896108,  1.81331864,  0.24454056, ...,  1.        ,
#          0.        ,  0.        ],
#        ...,
#        [ 1.12582258, -0.92052713,  1.52302674, ...,  1.        ,
#          0.        ,  0.        ],
#        [ 1.77785212, -0.2277552 , -0.38377708, ...,  1.        ,
#          0.        ,  0.        ],
#        [ 0.82944552, -0.95867683, -0.73836105, ...,  1.        ,
#          0.        ,  0.        ]])

# %%
#View the transformations
X_train_processed_df.describe().round(2)
# Out:
#        Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# count      6392.00          6392.00   6392.00                    6392.00
# mean         -0.00            -0.00      0.00                      -0.00
# std           1.00             1.00      1.00                       1.00
# min          -1.97            -1.29     -1.77                      -1.53
# 25%          -0.79            -0.76     -0.76                      -1.29
# 50%          -0.06            -0.23      0.03                       0.14
# 75%           0.77             0.56      0.72                       0.73
# max           2.01             5.13      1.99                       1.33
#
#        Item_Identifier_DRA12  Item_Identifier_DRA24  Item_Identifier_DRA59  \
# count                6392.00                6392.00                6392.00
# mean                    0.00                   0.00                   0.00
# std                     0.03                   0.03                   0.03
# min                     0.00                   0.00                   0.00
# 25%                     0.00                   0.00                   0.00
# 50%                     0.00                   0.00                   0.00
# 75%                     0.00                   0.00                   0.00
# max                     1.00                   1.00                   1.00
#
#        Item_Identifier_DRB01  Item_Identifier_DRB13  Item_Identifier_DRB24  \
# count                6392.00                6392.00                6392.00
# mean                    0.00                   0.00                   0.00
# std                     0.02                   0.03                   0.02
# min                     0.00                   0.00                   0.00
# 25%                     0.00                   0.00                   0.00
# 50%                     0.00                   0.00                   0.00
# 75%                     0.00                   0.00                   0.00
# max                     1.00                   1.00                   1.00
#
#        ...  Outlet_Size_Medium  Outlet_Size_Small  Outlet_Size_Unknown  \
# count  ...             6392.00            6392.00              6392.00
# mean   ...                0.33               0.28                 0.28
# std    ...                0.47               0.45                 0.45
# min    ...                0.00               0.00                 0.00
# 25%    ...                0.00               0.00                 0.00
# 50%    ...                0.00               0.00                 0.00
# 75%    ...                1.00               1.00                 1.00
# max    ...                1.00               1.00                 1.00
#
#        Outlet_Location_Type_Tier 1  Outlet_Location_Type_Tier 2  \
# count                      6392.00                      6392.00
# mean                          0.27                         0.33
# std                           0.45                         0.47
# min                           0.00                         0.00
# 25%                           0.00                         0.00
# 50%                           0.00                         0.00
# 75%                           1.00                         1.00
# max                           1.00                         1.00
#
#        Outlet_Location_Type_Tier 3  Outlet_Type_Grocery Store  \
# count                      6392.00                    6392.00
# mean                          0.40                       0.12
# std                           0.49                       0.33
# min                           0.00                       0.00
# 25%                           0.00                       0.00
# 50%                           0.00                       0.00
# 75%                           1.00                       0.00
# max                           1.00                       1.00
#
#        Outlet_Type_Supermarket Type1  Outlet_Type_Supermarket Type2  \
# count                        6392.00                        6392.00
# mean                            0.65                           0.11
# std                             0.48                           0.31
# min                             0.00                           0.00
# 25%                             0.00                           0.00
# 50%                             1.00                           0.00
# 75%                             1.00                           0.00
# max                             1.00                           1.00
#
#        Outlet_Type_Supermarket Type3
# count                        6392.00
# mean                            0.11
# std                             0.32
# min                             0.00
# 25%                             0.00
# 50%                             0.00
# 75%                             0.00
# max                             1.00
#
# [8 rows x 1593 columns]

# %%
#View the transformations
X_test_processed_df.describe().round(2)
# Out:
#        Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# count      2131.00          2131.00   2131.00                    2131.00
# mean         -0.04             0.01     -0.06                      -0.01
# std           1.01             1.04      0.98                       0.99
# min          -1.96            -1.29     -1.75                      -1.53
# 25%          -0.88            -0.76     -0.78                      -1.29
# 50%          -0.06            -0.24     -0.15                       0.14
# 75%           0.75             0.56      0.64                       0.73
# max           2.01             4.79      1.99                       1.33
#
#        Item_Identifier_DRA12  Item_Identifier_DRA24  Item_Identifier_DRA59  \
# count                2131.00                2131.00                2131.00
# mean                    0.00                   0.00                   0.00
# std                     0.03                   0.03                   0.03
# min                     0.00                   0.00                   0.00
# 25%                     0.00                   0.00                   0.00
# 50%                     0.00                   0.00                   0.00
# 75%                     0.00                   0.00                   0.00
# max                     1.00                   1.00                   1.00
#
#        Item_Identifier_DRB01  Item_Identifier_DRB13  Item_Identifier_DRB24  \
# count                 2131.0                 2131.0                2131.00
# mean                     0.0                    0.0                   0.00
# std                      0.0                    0.0                   0.03
# min                      0.0                    0.0                   0.00
# 25%                      0.0                    0.0                   0.00
# 50%                      0.0                    0.0                   0.00
# 75%                      0.0                    0.0                   0.00
# max                      0.0                    0.0                   1.00
#
#        ...  Outlet_Size_Medium  Outlet_Size_Small  Outlet_Size_Unknown  \
# count  ...             2131.00            2131.00              2131.00
# mean   ...                0.32               0.28                 0.28
# std    ...                0.47               0.45                 0.45
# min    ...                0.00               0.00                 0.00
# 25%    ...                0.00               0.00                 0.00
# 50%    ...                0.00               0.00                 0.00
# 75%    ...                1.00               1.00                 1.00
# max    ...                1.00               1.00                 1.00
#
#        Outlet_Location_Type_Tier 1  Outlet_Location_Type_Tier 2  \
# count                      2131.00                      2131.00
# mean                          0.30                         0.32
# std                           0.46                         0.47
# min                           0.00                         0.00
# 25%                           0.00                         0.00
# 50%                           0.00                         0.00
# 75%                           1.00                         1.00
# max                           1.00                         1.00
#
#        Outlet_Location_Type_Tier 3  Outlet_Type_Grocery Store  \
# count                      2131.00                    2131.00
# mean                          0.38                       0.13
# std                           0.49                       0.34
# min                           0.00                       0.00
# 25%                           0.00                       0.00
# 50%                           0.00                       0.00
# 75%                           1.00                       0.00
# max                           1.00                       1.00
#
#        Outlet_Type_Supermarket Type1  Outlet_Type_Supermarket Type2  \
# count                        2131.00                        2131.00
# mean                            0.66                           0.11
# std                             0.47                           0.31
# min                             0.00                           0.00
# 25%                             0.00                           0.00
# 50%                             1.00                           0.00
# 75%                             1.00                           0.00
# max                             1.00                           1.00
#
#        Outlet_Type_Supermarket Type3
# count                         2131.0
# mean                             0.1
# std                              0.3
# min                              0.0
# 25%                              0.0
# 50%                              0.0
# 75%                              0.0
# max                              1.0
#
# [8 rows x 1593 columns]

# %% [markdown]
# ### Fitting a Linear Regression Model

# %%
# Create an instance of the model
reg = LinearRegression()
reg_pipe = make_pipeline(preprocessor, reg)

reg_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('pipeline-1',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fd6b42e9450>),
#                                                  ('pipeline-2',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehotencoder',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse=False))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x7fd6b42ebb20>)],
#                                    verbose_feature_names_out=False)),
#                 ('linearregression', LinearRegression())])

# %%
# To obtain the predictions of the train set
train_preds = reg.predict(X_train_processed)
# To obtain the predictions of the test set
test_preds = reg.predict(X_test_processed)

# %% [markdown]
# ## Measuring Model Performance with R Squared

# %%
r2_train = r2_score(y_train, train_preds)
r2_test = r2_score(y_test, test_preds)

# %%
## Measuring model performance - using builtin .score()
print(f"Train R-Squared: { round( reg_pipe.score(X_train, y_train),2) }")
print(f"Test R-Squared: { round( reg_pipe.score(X_test, y_test),2) }")
# Out:
# Train R-Squared: 0.67
# Test R-Squared: -1.9509210668991644e+18

# %% [markdown]
# ## Measuring Model Performance with RMSE

# %%
rmse_train = np.sqrt(mean_squared_error(y_train, train_preds))
rmse_test = np.sqrt(mean_squared_error(y_test, test_preds))

# %%
# get predictions for train and test data
y_hat_train = reg_pipe.predict(X_train)
y_hat_test = reg_pipe.predict(X_test)

# %%
## Get RMSE for train vs test
rmse_train =  mean_squared_error(y_train, y_hat_train, squared=False)
rmse_test = mean_squared_error(y_test, y_hat_test, squared=False)
print(f"Train RMSE: { round(rmse_train, 2)}")
print(f"Test RMSE: { round( rmse_test, 2)}")
# Out:
# Train RMSE: 986.16
# Test RMSE: 2320031662257.72

# %% [markdown]
# ## Regression Tree Model

# %%
##Baseline
dec_tree = DecisionTreeRegressor(random_state = 42)

# %% [markdown]
# #### Training Model and Predictions

# %%
dec_tree.fit(X_train_processed, y_train)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
#Predict target values for training and test set
#Predict target values for training and test set
train_preds = dec_tree.predict(X_train_processed)
test_preds = dec_tree.predict(X_test_processed)

# %%
# Evaluate the model using default Metrics
train_score = dec_tree.score(X_train_processed, y_train)
test_score = dec_tree.score(X_test_processed, y_test)
print(f'Decision Tree Default Train R2 Score: {train_score}')
print(f'Decision Tree Default Test R2 Score: {test_score}')
# Out:
# Decision Tree Default Train R2 Score: 1.0
# Decision Tree Default Test R2 Score: 0.23130744552410698

# %% [markdown]
# ## And we can fine-tune the Model

# %%
# Looking at options for tuning this model
dec_tree.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'random_state': 42,
#  'splitter': 'best'}

# %% [markdown]
# #### But, we do not know the depth of tree, and the leaves. Let's find that out.

# %%
# Default tree Depth?
dec_tree.get_depth()
# Out:
# 60

# %%
# Default leaf nodes?
dec_tree.get_n_leaves()
# Out:
# 6259

# %% [markdown]
# ### Let's make a visual of the tree depths. To understand it better.

# %%
# List of values to try for max_depth:
max_depth_range = list(range(2, 44)) # will try every value between 2 and 44
# List to store the score for each value of max_depth:
r2 = []
for depth in max_depth_range:
    dec_tree = DecisionTreeRegressor(max_depth = depth, 
                             random_state = 42)
    dec_tree.fit(X_train_processed, y_train)
    score = dec_tree.score(X_test_processed, y_test)
    r2.append(score)

# %%
# Visualize which max_depth leads to the highest r2 score
import matplotlib.pyplot as plt
plt.plot(max_depth_range, r2)
plt.xlabel('max_depth')
plt.ylabel('R2');

# %% [markdown]
# ### Best version to use

# %% [markdown]
# The best maximum depth, seen above, is 5. Let's set that as the max depth.

# %%
 # Set max depth to 5
dec_tree_5 = DecisionTreeRegressor(max_depth = 5, random_state = 42)
dec_tree_5.fit(X_train_processed, y_train)
train_5_score = dec_tree_5.score(X_train_processed, y_train)
test_5_score = dec_tree_5.score(X_test_processed, y_test)
print(f'Decision Tree Tuned Train Score: {train_5_score}')
print(f'Decision Tree Tuned Test Score: {test_5_score}')
# Out:
# Decision Tree Tuned Train Score: 0.6042066848171654
# Decision Tree Tuned Test Score: 0.5960564372160062

# %% [markdown]
# ### Measuring Model Performance with RMSE

# %%
rmse_train = np.sqrt(mean_squared_error(y_train, train_preds))
rmse_test = np.sqrt(mean_squared_error(y_test, test_preds))

# %%
# get predictions for train and test data
y_hat_train = dec_tree_5.predict(X_train_processed_df)
y_hat_test = dec_tree_5.predict(X_test_processed_df)

# %%
# get predictions for train and test data
train_preds = dec_tree.predict(X_train_processed)
test_preds = dec_tree.predict(X_test_processed)

# %%
## Get RMSE for train vs test
rmse_train =  mean_squared_error(y_train, train_preds, squared=False)
rmse_test = mean_squared_error(y_test, test_preds, squared=False)
print(f"Train RMSE: { round(rmse_train, 2)}")
print(f"Test RMSE: { round( rmse_test, 2)}")
# Out:
# Train RMSE: 146.64
# Test RMSE: 1449.14

# %%
y_pred = dec_tree_5.predict(X_test_processed)

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print(f'Decision Tree Model Testing Mean Absolute Error: {mae}')
print(f'Decision Tree Model Testing Mean Squared Error: {mse}')
print(f'Decision Tree Model Testing Root Mean Squared Error: {rmse}')
print(f'Decision Tree Model Testing R-squared: {r2}')
# Out:
# Decision Tree Model Testing Mean Absolute Error: 736.8796499354125
# Decision Tree Model Testing Mean Squared Error: 1114471.1152767404
# Decision Tree Model Testing Root Mean Squared Error: 1055.6851402178304
# Decision Tree Model Testing R-squared: 0.5960564372160062

# %% [markdown]
# #### For The Stakeholders:
#
# - By using the Mean Absolute Model, we can see the error has the lowest. We can utilize that to make future predictions.
